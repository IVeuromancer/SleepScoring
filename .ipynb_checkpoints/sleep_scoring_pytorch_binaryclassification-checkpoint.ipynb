# %%
#import packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# from random import randrange, sample
from sklearn.preprocessing import StandardScaler
# from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, accuracy_score
import mne
from pickle import dump, load
import torch
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset, random_split, Subset
import torch.nn as nn
import torch.nn.functional as F
from collections import Counter
import joblib

# %%
EEG_files = ['../../code/LabCode/Fiber_photometry/mouse_653/mouse_653_230316.edf',
            '../../code/LabCode/Fiber_photometry/mouse_807/mouse_807_230511.edf', 
            '../../code/LabCode/Fiber_photometry/mouse_838/mouse_838_230525.edf', 
            '../../code/LabCode/Fiber_photometry/mouse_994/mouse_994_230713.edf', 
            '../../code/LabCode/Fiber_photometry/mouse_998/mouse_998_230727.edf', 
            '../../code/LabCode/Fiber_photometry/mouse_1002/mouse_1002_230725.edf',
            '../../code/LabCode/Fiber_photometry/mouse_569/mouse_569_240214.edf',
            '../../code/LabCode/Fiber_photometry/mouse_569/mouse_569_240215.edf',
            '../../code/LabCode/Fiber_photometry/mouse_564/mouse_564_240221.edf']
scores_files = ['../../code/LabCode/Fiber_photometry/mouse_653/mouse_653_230316_scores.tsv',
                '../../code/LabCode/Fiber_photometry/mouse_807/mouse_807_230511_scores.tsv',
                '../../code/LabCode/Fiber_photometry/mouse_838/mouse_838_230525_scores.tsv', 
                '../../code/LabCode/Fiber_photometry/mouse_998/mouse_998_230727_scores.tsv', 
                '../../code/LabCode/Fiber_photometry/mouse_994/mouse_994_230713_scores.tsv', 
                '../../code/LabCode/Fiber_photometry/mouse_1002/mouse_1002_230725_scores.tsv',
               '../../code/LabCode/Fiber_photometry/mouse_569/mouse_569_240214_scores.tsv',
               '../../code/LabCode/Fiber_photometry/mouse_569/mouse_569_240215_scores.tsv',
               '../../code/LabCode/Fiber_photometry/mouse_564/mouse_564_240221_scores.tsv']
EMG_side = ['both',
           'R',
           'R', # L is better, but didn't save it, it's okay
           'both',
           'both',
           'L',
           'L',
           'L',
           'L']
epoch_limits = 8640
epoch_sum = epoch_limits*len(EEG_files)

# %%
all_data = []
scores_converted = []
for EEG,scores_l,side in zip(EEG_files,scores_files,EMG_side):
    raw = mne.io.read_raw_edf(EEG, preload=True, verbose = False)
    sf = raw.info['sfreq']
    print('Data shape (channels, times) =', raw._data.shape)
    scores = pd.read_csv(scores_l, skiprows=10, delim_whitespace=True)
    scores_array = scores['Time.2']
    for i in range(epoch_limits): 
        if side == 'both' or side == 'R':
            all_data.append([raw._data[0][i*1280:(i+1)*1280], raw._data[1][i*1280:(i+1)*1280], raw._data[2][i*1280:(i+1)*1280]]) 
        else:
            all_data.append([raw._data[0][i*1280:(i+1)*1280], raw._data[1][i*1280:(i+1)*1280], raw._data[3][i*1280:(i+1)*1280]])
    # in sirenia sleep, 255 unscored, 1 wake, 2 NREM, 3 REM, 4 "parameters"
    # in Yasa -2 = Unscored, -1 = Artefact / Movement, 0 = Wake, 1 = N1 sleep, 2 = N2 sleep, 3 = N3 sleep, 4 = REM sleep
    # for sleep scoring code -2 = Unscored, -1 = Artefact / Movement, 0 = Wake, 1 = N1 sleep, 1 = N2 sleep, 1 = N3 sleep, 2 = REM sleep
        if scores_array[i]==1: # wake
            scores_converted.append(0)
        elif scores_array[i]==2: # NREM
            scores_converted.append(1)
        elif scores_array[i]==3: # REM
            scores_converted.append(2)
        elif scores_array[i]==255: # unscored
            scores_converted.append(-2)      
y = np.array(scores_converted).reshape(epoch_sum,1)
data = np.array(all_data)
# Out:
# Data shape (channels, times) = (3, 11060096)
# Data shape (channels, times) = (3, 11060224)
# Data shape (channels, times) = (3, 11060224)
# Data shape (channels, times) = (4, 11060224)
# Data shape (channels, times) = (4, 11060224)
# Data shape (channels, times) = (4, 11060224)
# Data shape (channels, times) = (4, 11059200)
# Data shape (channels, times) = (4, 11060096)
# Data shape (channels, times) = (4, 11060096)

# %%
scaler_CH1 = StandardScaler().fit(data[:,0,:])
scaler_CH2 = StandardScaler().fit(data[:,1,:])
scaler_CH3 = StandardScaler().fit(data[:,2,:])

data_CH1_normalized = scaler_CH1.transform(data[:, 0, :])
data_CH2_normalized = scaler_CH2.transform(data[:, 1, :])
data_CH3_normalized = scaler_CH3.transform(data[:, 2, :])

X = np.stack((data_CH1_normalized,data_CH2_normalized,data_CH3_normalized),axis=1)

# %%
# joblib.dump(scaler_CH1, 'scaler_CH1.pkl')
# joblib.dump(scaler_CH2, 'scaler_CH2.pkl')
# joblib.dump(scaler_CH3, 'scaler_CH3.pkl')
# Out:
# ['scaler_CH3.pkl']

# %%
# scalers = []
# normalized_data = []

# for sample in range(data.shape[0]):
#     sample_data = []
#     for channel in range(data.shape[1]):
#         scaler = StandardScaler().fit(data[sample, channel, :].reshape((-1,1)))
#         scalers.append(scaler)
#         normalized_segment = scaler.transform(data[sample, channel, :].reshape((-1,1)))
#         sample_data.append(normalized_segment)
#     normalized_data.append(np.stack(sample_data, axis=0))

# normalized_data = np.array(normalized_data)
# X = normalized_data.reshape((51840,3,1280))

# %%
num_mouse = len(EEG_files)
# Convert your data to tensors
X_tensor = torch.tensor(X, dtype=torch.float32)
y_tensor = torch.tensor(y, dtype=torch.long).squeeze()

# Create a list to hold datasets for each mouse
datasets = []

# Calculate the number of epochs per third of mouse recording 
epochs_per_thirdmouse = X.shape[0] // (num_mouse*3) # 8640

# Split data by mouse
for i in range(num_mouse*3):
    start_idx = i * epochs_per_thirdmouse
    end_idx = start_idx + epochs_per_thirdmouse
    thirdmouse_dataset = TensorDataset(X_tensor[start_idx:end_idx], y_tensor[start_idx:end_idx])
    datasets.append(thirdmouse_dataset)

# %%
# Split each mouse's data into training, validation, and test sets
train_datasets = []
val_datasets = []
test_datasets = []

for mouse_dataset in datasets:
    # Define the sizes for training, validation, and test sets (e.g., 70%, 15%, 15%)
    train_size = int(0.7 * len(mouse_dataset))
    val_size = int(0.15 * len(mouse_dataset))
    test_size = len(mouse_dataset) - train_size - val_size
    # Split the dataset
    train_data = torch.utils.data.Subset(mouse_dataset, range(train_size))
    val_data = torch.utils.data.Subset(mouse_dataset, range(train_size, train_size + val_size))
    test_data = torch.utils.data.Subset(mouse_dataset, range(train_size + val_size, len(mouse_dataset)))

#     train_data, val_data, test_data = random_split(mouse_dataset, [train_size, val_size, test_size])
    
    # Append to the lists
    train_datasets.append(train_data)
    val_datasets.append(val_data)
    test_datasets.append(test_data)

# Concatenate datasets from all mice to create the final training, validation, and test sets
train_dataset = torch.utils.data.ConcatDataset(train_datasets)
val_dataset = torch.utils.data.ConcatDataset(val_datasets)
test_dataset = torch.utils.data.ConcatDataset(test_datasets)

# %%
# Create data loaders
batch_size = 64
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=False)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %%
# Check for GPU availability
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

class SleepScoringModel(nn.Module):
    def __init__(self, dropout_rate=0.5, weight_decay=1e-4):
        super(SleepScoringModel, self).__init__()
        
        self.conv1 = nn.Conv1d(3, 32, kernel_size=3, stride=1, padding=1)
        self.conv2 = nn.Conv1d(32, 64, kernel_size=3, stride=1, padding=1)
        
        # Add dropout layers
        self.dropout1 = nn.Dropout(dropout_rate)
        self.dropout2 = nn.Dropout(dropout_rate)
        
        self.fc1 = nn.Linear(64 * 1280, 128)
        self.fc2 = nn.Linear(128, 3)
        
        # Add weight decay to the optimizer (e.g., Adam)
        self.weight_decay = weight_decay

    def forward(self, x):
        x = self.conv1(x)
        x = F.relu(x)
        x = self.dropout1(x)  # Apply dropout
        x = self.conv2(x)
        x = F.relu(x)
        x = self.dropout2(x)  # Apply dropout
        x = x.view(x.size(0), -1)
        x = self.fc1(x)
        x = F.relu(x)
        x = self.fc2(x)
        return x

# Create an instance of the model
model = SleepScoringModel().to(device)

# %%
class_occurrence = Counter()
for _, labels in train_loader:
    # Assuming labels is a tensor containing class labels
    class_occurrence.update(labels.numpy())

# Print the class occurrences
print("Class Occurrences:", class_occurrence)
class_occurences = [class_occurrence[0],class_occurrence[1],class_occurrence[2]]
print(class_occurences)
# Out:
# Class Occurrences: Counter({0: 27071, 1: 24282, 2: 3052})
# [27071, 24282, 3052]

# %%
# Step 2: Define the Loss Function and Optimizer
total_samples = len(train_dataset)
class_counts = []
for i in class_occurences:
    class_counts.append(i/total_samples)
class_weights = 1.0 / torch.tensor(class_counts)
print(class_weights)
class_weights = class_weights.to(device)
# Out:
# tensor([ 2.0097,  2.2405, 17.8260])

# %%
criterion = nn.CrossEntropyLoss(weight=class_weights)
optimizer = optim.Adam(model.parameters(), lr=0.001, weight_decay=model.weight_decay)

# %%
# Initialize variables for early stopping
best_val_loss = float('inf')  # Initialize the best validation loss to infinity
patience = 5  # Number of epochs without improvement
no_improve_epochs = 0  # Initialize the count of epochs without improvement

# Initialize empty lists to store training and validation loss and accuracy values
train_losses = []
train_accuracies = []
val_losses = []
val_accuracies = []

# Training Loop
num_epochs = 60

for epoch in range(num_epochs):
    model.train()  # Set the model to training mode
    correct = 0
    total = 0
    running_loss = 0.0
    
    for batch_X, batch_y in train_loader:
        batch_X, batch_y = batch_X.to(device), batch_y.to(device)
        optimizer.zero_grad()
        outputs = model(batch_X)
        loss = criterion(outputs, batch_y.squeeze())
        loss.backward()
        optimizer.step()
        
        # Compute accuracy for the batch
        _, predicted = torch.max(outputs.data, 1)
        total += batch_y.size(0)
        correct += (predicted == batch_y.squeeze()).sum().item()
        
        running_loss += loss.item() * batch_X.size(0)
    
    epoch_loss = running_loss / len(train_loader.dataset)
    epoch_accuracy = correct / total
    
    train_losses.append(epoch_loss)
    train_accuracies.append(epoch_accuracy)
    
    print(f"Epoch [{epoch+1}/{num_epochs}], Training Loss: {epoch_loss:.4f}, Training Accuracy: {epoch_accuracy:.4f}")

    # Validation Evaluation
    model.eval()  # Set the model to evaluation mode
    correct_val = 0
    total_val = 0
    running_loss_val = 0.0
    all_pred_labels = []
    all_true_labels = []
    
    with torch.no_grad():  # Disable gradient computation for validation
        for batch_X_val, batch_y_val in val_loader:
            batch_X_val, batch_y_val = batch_X_val.to(device), batch_y_val.to(device)
            outputs_val = model(batch_X_val)
            loss_val = criterion(outputs_val, batch_y_val.squeeze())
            
            # Compute accuracy for the validation batch
            _, predicted_val = torch.max(outputs_val.data, 1)
            total_val += batch_y_val.size(0)
            correct_val += (predicted_val == batch_y_val.squeeze()).sum().item()
            
            running_loss_val += loss_val.item() * batch_X_val.size(0)
            all_pred_labels.extend(predicted_val.cpu().numpy())
            all_true_labels.extend(batch_y_val.cpu().numpy())
            
    epoch_loss_val = running_loss_val / len(val_loader.dataset)
    epoch_accuracy_val = correct_val / total_val
    
    val_losses.append(epoch_loss_val)
    val_accuracies.append(epoch_accuracy_val)
    
    # Compute the confusion matrix
    conf_matrix = confusion_matrix(all_true_labels, all_pred_labels)

    # Calculate class-wise accuracy
    class_accuracy = conf_matrix.diagonal() / conf_matrix.sum(axis=1)
    
    print(f"Validation Loss: {epoch_loss_val:.4f}, Validation Accuracy: {epoch_accuracy_val:.4f}")
    for i, accuracy in enumerate(class_accuracy):
        print(f"Class {i}: Accuracy = {accuracy:.4f}")


#     # Check for early stopping based on validation loss
#     if epoch_loss_val < best_val_loss:
#         best_val_loss = epoch_loss_val  # Update the best validation loss
#         no_improve_epochs = 0  # Reset the count of epochs without improvement
#     else:
#         no_improve_epochs += 1  # Increment the count of epochs without improvement

#     # If no improvement for 'patience' epochs, stop training
#     if no_improve_epochs >= patience:
#         print(f"Early stopping after {epoch+1} epochs without improvement.")
#         break
# Out:
# Epoch [1/60], Training Loss: 1.1015, Training Accuracy: 0.4913
# Validation Loss: 1.0950, Validation Accuracy: 0.4090
# Class 0: Accuracy = 1.0000
# Class 1: Accuracy = 0.0000
# Class 2: Accuracy = 0.0000
# Epoch [2/60], Training Loss: 1.0569, Training Accuracy: 0.4976
# Validation Loss: 1.1008, Validation Accuracy: 0.4090
# Class 0: Accuracy = 1.0000
# Class 1: Accuracy = 0.0000
# Class 2: Accuracy = 0.0000
# Epoch [3/60], Training Loss: 1.0541, Training Accuracy: 0.4976
# Validation Loss: 1.1051, Validation Accuracy: 0.4090
# Class 0: Accuracy = 1.0000
# Class 1: Accuracy = 0.0000
# Class 2: Accuracy = 0.0000
# Epoch [4/60], Training Loss: 1.0529, Training Accuracy: 0.4976
# Validation Loss: 1.1077, Validation Accuracy: 0.4090
# Class 0: Accuracy = 1.0000
# Class 1: Accuracy = 0.0000
# Class 2: Accuracy = 0.0000
# Epoch [5/60], Training Loss: 1.0530, Training Accuracy: 0.4975
# Validation Loss: 1.1090, Validation Accuracy: 0.4090
# Class 0: Accuracy = 1.0000
# Class 1: Accuracy = 0.0000
# Class 2: Accuracy = 0.0000
# Epoch [6/60], Training Loss: 1.0430, Training Accuracy: 0.5203
# Validation Loss: 3.0357, Validation Accuracy: 0.6394
# Class 0: Accuracy = 0.3604
# Class 1: Accuracy = 0.9555
# Class 2: Accuracy = 0.0000
# Epoch [7/60], Training Loss: 1.0016, Training Accuracy: 0.6456
# Validation Loss: 8.1582, Validation Accuracy: 0.6581
# Class 0: Accuracy = 0.8281
# Class 1: Accuracy = 0.6204
# Class 2: Accuracy = 0.0000
# Epoch [8/60], Training Loss: 0.8448, Training Accuracy: 0.7249
# Validation Loss: 15.5406, Validation Accuracy: 0.6359
# Class 0: Accuracy = 0.9065
# Class 1: Accuracy = 0.5150
# Class 2: Accuracy = 0.0000
# Epoch [9/60], Training Loss: 0.9093, Training Accuracy: 0.7400
# Validation Loss: 7.8670, Validation Accuracy: 0.5887
# Class 0: Accuracy = 0.8526
# Class 1: Accuracy = 0.4662
# Class 2: Accuracy = 0.0000
# Epoch [10/60], Training Loss: 0.8591, Training Accuracy: 0.7660
# Validation Loss: 28.1347, Validation Accuracy: 0.5754
# Class 0: Accuracy = 0.8964
# Class 1: Accuracy = 0.4056
# Class 2: Accuracy = 0.0000
# Epoch [11/60], Training Loss: 0.9849, Training Accuracy: 0.7502
# Validation Loss: 1.1216, Validation Accuracy: 0.6551
# Class 0: Accuracy = 0.7147
# Class 1: Accuracy = 0.7046
# Class 2: Accuracy = 0.0000
# Epoch [12/60], Training Loss: 0.8806, Training Accuracy: 0.7380
# Validation Loss: 12.9580, Validation Accuracy: 0.5648
# Class 0: Accuracy = 0.8587
# Class 1: Accuracy = 0.3903
# Class 2: Accuracy = 0.1667
# Epoch [13/60], Training Loss: 0.7771, Training Accuracy: 0.7599
# Validation Loss: 6.4550, Validation Accuracy: 0.6467
# Class 0: Accuracy = 0.8176
# Class 1: Accuracy = 0.5240
# Class 2: Accuracy = 0.5586
# Epoch [14/60], Training Loss: 0.7938, Training Accuracy: 0.7668
# Validation Loss: 10.8727, Validation Accuracy: 0.6169
# Class 0: Accuracy = 0.8962
# Class 1: Accuracy = 0.4131
# Class 2: Accuracy = 0.4955
# Epoch [15/60], Training Loss: 0.6999, Training Accuracy: 0.7740
# Validation Loss: 0.9085, Validation Accuracy: 0.6811
# Class 0: Accuracy = 0.8034
# Class 1: Accuracy = 0.6002
# Class 2: Accuracy = 0.5709
# Epoch [16/60], Training Loss: 0.6274, Training Accuracy: 0.7766
# Validation Loss: 23.2671, Validation Accuracy: 0.5628
# Class 0: Accuracy = 0.9778
# Class 1: Accuracy = 0.2509
# Class 2: Accuracy = 0.4437
# Epoch [17/60], Training Loss: 0.6262, Training Accuracy: 0.7860
# Validation Loss: 3.3303, Validation Accuracy: 0.6021
# Class 0: Accuracy = 0.9050
# Class 1: Accuracy = 0.3771
# Class 2: Accuracy = 0.4966
# Epoch [18/60], Training Loss: 0.5848, Training Accuracy: 0.7849
# Validation Loss: 5.0693, Validation Accuracy: 0.6389
# Class 0: Accuracy = 0.8881
# Class 1: Accuracy = 0.4675
# Class 2: Accuracy = 0.4595
# Epoch [19/60], Training Loss: 0.6375, Training Accuracy: 0.7882
# Validation Loss: 2.2891, Validation Accuracy: 0.6637
# Class 0: Accuracy = 0.9086
# Class 1: Accuracy = 0.4945
# Class 2: Accuracy = 0.4921
# Epoch [20/60], Training Loss: 0.5636, Training Accuracy: 0.7928
# Validation Loss: 1.3132, Validation Accuracy: 0.6655
# Class 0: Accuracy = 0.9325
# Class 1: Accuracy = 0.4838
# Class 2: Accuracy = 0.4595
# Epoch [21/60], Training Loss: 0.5161, Training Accuracy: 0.8026
# Validation Loss: 1.0771, Validation Accuracy: 0.6933
# Class 0: Accuracy = 0.9195
# Class 1: Accuracy = 0.5523
# Class 2: Accuracy = 0.4324
# Epoch [22/60], Training Loss: 0.4747, Training Accuracy: 0.8075
# Validation Loss: 2.4327, Validation Accuracy: 0.7010
# Class 0: Accuracy = 0.9306
# Class 1: Accuracy = 0.5485
# Class 2: Accuracy = 0.5000
# Epoch [23/60], Training Loss: 0.4592, Training Accuracy: 0.8120
# Validation Loss: 1.5671, Validation Accuracy: 0.6713
# Class 0: Accuracy = 0.9558
# Class 1: Accuracy = 0.4754
# Class 2: Accuracy = 0.4685
# Epoch [24/60], Training Loss: 0.4620, Training Accuracy: 0.8112
# Validation Loss: 1.1878, Validation Accuracy: 0.6680
# Class 0: Accuracy = 0.9539
# Class 1: Accuracy = 0.4745
# Class 2: Accuracy = 0.4414
# Epoch [25/60], Training Loss: 0.4352, Training Accuracy: 0.8178
# Validation Loss: 1.1181, Validation Accuracy: 0.6989
# Class 0: Accuracy = 0.9371
# Class 1: Accuracy = 0.5420
# Class 2: Accuracy = 0.4809
# Epoch [26/60], Training Loss: 0.4080, Training Accuracy: 0.8227
# Validation Loss: 1.3073, Validation Accuracy: 0.7042
# Class 0: Accuracy = 0.9287
# Class 1: Accuracy = 0.5573
# Class 2: Accuracy = 0.4921
# Epoch [27/60], Training Loss: 0.4011, Training Accuracy: 0.8238
# Validation Loss: 1.1526, Validation Accuracy: 0.7110
# Class 0: Accuracy = 0.9025
# Class 1: Accuracy = 0.5872
# Class 2: Accuracy = 0.5191
# Epoch [28/60], Training Loss: 0.3761, Training Accuracy: 0.8332
# Validation Loss: 1.4659, Validation Accuracy: 0.7047
# Class 0: Accuracy = 0.9354
# Class 1: Accuracy = 0.5418
# Class 2: Accuracy = 0.5676
# Epoch [29/60], Training Loss: 0.6570, Training Accuracy: 0.8319
# Validation Loss: 2.2068, Validation Accuracy: 0.7079
# Class 0: Accuracy = 0.9474
# Class 1: Accuracy = 0.5403
# Class 2: Accuracy = 0.5552
# Epoch [30/60], Training Loss: 0.4177, Training Accuracy: 0.8292
# Validation Loss: 1.4985, Validation Accuracy: 0.7209
# Class 0: Accuracy = 0.9197
# Class 1: Accuracy = 0.5921
# Class 2: Accuracy = 0.5248
# Epoch [31/60], Training Loss: 0.3617, Training Accuracy: 0.8385
# Validation Loss: 1.1965, Validation Accuracy: 0.7223
# Class 0: Accuracy = 0.9107
# Class 1: Accuracy = 0.6002
# Class 2: Accuracy = 0.5360
# Epoch [32/60], Training Loss: 0.5004, Training Accuracy: 0.8319
# Validation Loss: 2.8905, Validation Accuracy: 0.7150
# Class 0: Accuracy = 0.9442
# Class 1: Accuracy = 0.5569
# Class 2: Accuracy = 0.5529
# Epoch [33/60], Training Loss: 0.3880, Training Accuracy: 0.8363
# Validation Loss: 1.4922, Validation Accuracy: 0.7299
# Class 0: Accuracy = 0.9375
# Class 1: Accuracy = 0.5882
# Class 2: Accuracy = 0.5732
# Epoch [34/60], Training Loss: 0.4019, Training Accuracy: 0.8430
# Validation Loss: 1.8980, Validation Accuracy: 0.7205
# Class 0: Accuracy = 0.9335
# Class 1: Accuracy = 0.5783
# Class 2: Accuracy = 0.5383
# Epoch [35/60], Training Loss: 0.3357, Training Accuracy: 0.8421
# Validation Loss: 1.0825, Validation Accuracy: 0.7317
# Class 0: Accuracy = 0.9107
# Class 1: Accuracy = 0.6164
# Class 2: Accuracy = 0.5507
# Epoch [36/60], Training Loss: 0.3182, Training Accuracy: 0.8519
# Validation Loss: 0.9478, Validation Accuracy: 0.7335
# Class 0: Accuracy = 0.8929
# Class 1: Accuracy = 0.6344
# Class 2: Accuracy = 0.5473
# Epoch [37/60], Training Loss: 0.3052, Training Accuracy: 0.8514
# Validation Loss: 1.4380, Validation Accuracy: 0.7363
# Class 0: Accuracy = 0.8948
# Class 1: Accuracy = 0.6352
# Class 2: Accuracy = 0.5687
# Epoch [38/60], Training Loss: 0.3986, Training Accuracy: 0.8470
# Validation Loss: 1.2148, Validation Accuracy: 0.7551
# Class 0: Accuracy = 0.8904
# Class 1: Accuracy = 0.6670
# Class 2: Accuracy = 0.6239
# Epoch [39/60], Training Loss: 0.3163, Training Accuracy: 0.8585
# Validation Loss: 1.1702, Validation Accuracy: 0.7395
# Class 0: Accuracy = 0.9147
# Class 1: Accuracy = 0.6195
# Class 2: Accuracy = 0.6104
# Epoch [40/60], Training Loss: 0.3087, Training Accuracy: 0.8558
# Validation Loss: 1.5009, Validation Accuracy: 0.7497
# Class 0: Accuracy = 0.8172
# Class 1: Accuracy = 0.7155
# Class 2: Accuracy = 0.6182
# Epoch [41/60], Training Loss: 0.2898, Training Accuracy: 0.8639
# Validation Loss: 1.1183, Validation Accuracy: 0.7447
# Class 0: Accuracy = 0.8935
# Class 1: Accuracy = 0.6472
# Class 2: Accuracy = 0.6047
# Epoch [42/60], Training Loss: 0.2941, Training Accuracy: 0.8655
# Validation Loss: 1.1881, Validation Accuracy: 0.7422
# Class 0: Accuracy = 0.8832
# Class 1: Accuracy = 0.6623
# Class 2: Accuracy = 0.5248
# Epoch [43/60], Training Loss: 0.2823, Training Accuracy: 0.8694
# Validation Loss: 1.2732, Validation Accuracy: 0.7401
# Class 0: Accuracy = 0.7493
# Class 1: Accuracy = 0.7612
# Class 2: Accuracy = 0.5473
# Epoch [44/60], Training Loss: 0.2875, Training Accuracy: 0.8681
# Validation Loss: 1.0437, Validation Accuracy: 0.7411
# Class 0: Accuracy = 0.8910
# Class 1: Accuracy = 0.6447
# Class 2: Accuracy = 0.5878
# Epoch [45/60], Training Loss: 0.2619, Training Accuracy: 0.8729
# Validation Loss: 1.1254, Validation Accuracy: 0.7438
# Class 0: Accuracy = 0.8388
# Class 1: Accuracy = 0.6913
# Class 2: Accuracy = 0.5890
# Epoch [46/60], Training Loss: 0.4928, Training Accuracy: 0.8562
# Validation Loss: 0.9880, Validation Accuracy: 0.7640
# Class 0: Accuracy = 0.8143
# Class 1: Accuracy = 0.7511
# Class 2: Accuracy = 0.5811
# Epoch [47/60], Training Loss: 0.2877, Training Accuracy: 0.8682
# Validation Loss: 1.4229, Validation Accuracy: 0.7485
# Class 0: Accuracy = 0.7574
# Class 1: Accuracy = 0.7617
# Class 2: Accuracy = 0.6115
# Epoch [48/60], Training Loss: 0.2553, Training Accuracy: 0.8741
# Validation Loss: 1.2093, Validation Accuracy: 0.7593
# Class 0: Accuracy = 0.8386
# Class 1: Accuracy = 0.7303
# Class 2: Accuracy = 0.5304
# Epoch [49/60], Training Loss: 0.2323, Training Accuracy: 0.8829
# Validation Loss: 1.4339, Validation Accuracy: 0.7561
# Class 0: Accuracy = 0.8377
# Class 1: Accuracy = 0.7135
# Class 2: Accuracy = 0.6059
# Epoch [50/60], Training Loss: 0.2452, Training Accuracy: 0.8823
# Validation Loss: 1.1793, Validation Accuracy: 0.7480
# Class 0: Accuracy = 0.8189
# Class 1: Accuracy = 0.7174
# Class 2: Accuracy = 0.5743
# Epoch [51/60], Training Loss: 0.2311, Training Accuracy: 0.8860
# Validation Loss: 1.1682, Validation Accuracy: 0.7527
# Class 0: Accuracy = 0.8145
# Class 1: Accuracy = 0.7304
# Class 2: Accuracy = 0.5721
# Epoch [52/60], Training Loss: 0.2311, Training Accuracy: 0.8873
# Validation Loss: 1.4667, Validation Accuracy: 0.7406
# Class 0: Accuracy = 0.8468
# Class 1: Accuracy = 0.6863
# Class 2: Accuracy = 0.5372
# Epoch [53/60], Training Loss: 0.2336, Training Accuracy: 0.8855
# Validation Loss: 1.1297, Validation Accuracy: 0.7559
# Class 0: Accuracy = 0.8082
# Class 1: Accuracy = 0.7394
# Class 2: Accuracy = 0.5867
# Epoch [54/60], Training Loss: 0.2303, Training Accuracy: 0.8909
# Validation Loss: 1.3037, Validation Accuracy: 0.7509
# Class 0: Accuracy = 0.8029
# Class 1: Accuracy = 0.7383
# Class 2: Accuracy = 0.5563
# Epoch [55/60], Training Loss: 0.2510, Training Accuracy: 0.8926
# Validation Loss: 1.3223, Validation Accuracy: 0.7472
# Class 0: Accuracy = 0.7973
# Class 1: Accuracy = 0.7238
# Class 2: Accuracy = 0.6363
# Epoch [56/60], Training Loss: 0.2282, Training Accuracy: 0.8908
# Validation Loss: 1.2942, Validation Accuracy: 0.7592
# Class 0: Accuracy = 0.7795
# Class 1: Accuracy = 0.7669
# Class 2: Accuracy = 0.5980
# Epoch [57/60], Training Loss: 0.2267, Training Accuracy: 0.8952
# Validation Loss: 1.2661, Validation Accuracy: 0.7503
# Class 0: Accuracy = 0.8220
# Class 1: Accuracy = 0.7145
# Class 2: Accuracy = 0.6070
# Epoch [58/60], Training Loss: 0.2378, Training Accuracy: 0.8909
# Validation Loss: 0.9440, Validation Accuracy: 0.7569
# Class 0: Accuracy = 0.8015
# Class 1: Accuracy = 0.7361
# Class 2: Accuracy = 0.6577
# Epoch [59/60], Training Loss: 0.2450, Training Accuracy: 0.8983
# Validation Loss: 1.0783, Validation Accuracy: 0.7609
# Class 0: Accuracy = 0.8086
# Class 1: Accuracy = 0.7436
# Class 2: Accuracy = 0.6216
# Epoch [60/60], Training Loss: 0.2166, Training Accuracy: 0.8978
# Validation Loss: 1.1539, Validation Accuracy: 0.7516
# Class 0: Accuracy = 0.8212
# Class 1: Accuracy = 0.7229
# Class 2: Accuracy = 0.5721

# %%
import matplotlib.pyplot as plt

# Plotting Loss and Accuracy
plt.figure(figsize=(12, 4))

# Plot Training Loss
plt.subplot(1, 2, 1)
plt.plot(train_losses, label='Training Loss')
plt.plot(val_losses, label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.ylim([0,5])
plt.legend()

# Plot Training Accuracy
plt.subplot(1, 2, 2)
plt.plot(train_accuracies, label='Training Accuracy', color='r')
plt.plot(val_accuracies, label='Validation Accuracy', color='g')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')

plt.legend()

plt.tight_layout()
plt.show()

# %%
# Set the model to evaluation mode
model.eval()

# Initialize lists to store predicted and true labels
all_pred_labels = []
all_true_labels = []

# Iterate through the testing DataLoader
with torch.no_grad():  # Disable gradient computation for inference
    for batch_X_test, batch_y_test in test_loader:
        # Move the batch of data and labels to the device
        batch_X_test, batch_y_test = batch_X_test.to(device), batch_y_test.to(device)
        
        # Perform a forward pass through the model
        outputs_test = model(batch_X_test)
        
        # Compute the predicted labels
        _, predicted_test = torch.max(outputs_test, 1)
        
        # Accumulate the predicted labels and true labels
        all_pred_labels.extend(predicted_test.cpu().numpy())
        all_true_labels.extend(batch_y_test.cpu().numpy())

# Convert lists to NumPy arrays for further analysis
all_pred_labels = np.array(all_pred_labels)
all_true_labels = np.array(all_true_labels)

# Compute overall accuracy
accuracy_overall = accuracy_score(all_true_labels, all_pred_labels)
print(f"Overall Testing Accuracy: {accuracy_overall:.4f}")

# Compute class-wise accuracy
for i in range(3):  # Assuming 3 classes (wake, NREM, REM)
    class_accuracy = accuracy_score(all_true_labels == i, all_pred_labels == i)
    print(f"Class {i} Accuracy: {class_accuracy:.4f}")
# Out:
# Overall Testing Accuracy: 0.8172
# Class 0 Accuracy: 0.8373
# Class 1 Accuracy: 0.8251
# Class 2 Accuracy: 0.9720

# %%
# def initialize_model(model):
#     # Initialize model parameters here
#     for param in model.parameters():
#         if param.requires_grad:
#             nn.init.xavier_uniform_(param.data)
# initialize_model(model)

# %%
# Define the file path to save the model
# model_path = 'sleep_scoring_model_240222.pth'

# # Save the model's state_dict to the file path
# torch.save(model.state_dict(), model_path)

# print(f"Model saved to {model_path}")
# Out:
# Model saved to sleep_scoring_model_240222.pth

# %%
# Define the file path to load the model
model_path = 'sleep_scoring_model_240109.pth'

# Initialize a new model instance with the same architecture
model = SleepScoringModel().to(device)

# Load the model's state_dict from the file path
model.load_state_dict(torch.load(model_path, map_location=device))

print(f"Model loaded from {model_path}")

# %%
# # Assume `device` is already defined (e.g., device = torch.device('cuda' if torch.cuda.is_available() else 'cpu'))

# # Define a function to preprocess a single sample of data
# def preprocess_single_sample(single_sample):
#     # Implement the preprocessing steps required for your model
#     # ...
#     return preprocessed_sample

# # Define a function to make real-time predictions for a single sample
# def predict_single_sample(model, single_sample):
#     # Preprocess the single sample
#     preprocessed_sample = preprocess_single_sample(single_sample)
    
#     # Convert the preprocessed sample to a PyTorch tensor and move it to the device
#     tensor_sample = torch.tensor(preprocessed_sample, dtype=torch.float32).unsqueeze(0).to(device)
    
#     # Set the model to evaluation mode
#     model.eval()
    
#     # Perform a forward pass through the model
#     with torch.no_grad():  # Disable gradient computation for inference
#         outputs = model(tensor_sample)
    
#     # Optionally, convert the predicted outputs to probabilities using a softmax function
#     # probabilities = torch.softmax(outputs, dim=1)
    
#     # Convert the predicted outputs to class labels
#     _, predicted_label = torch.max(outputs, 1)
    
#     # Convert the predicted class label to human-readable format
#     class_label = convert_to_human_readable(predicted_label.item())  # Assume `convert_to_human_readable` is a function that converts numerical labels to human-readable format
    
#     return class_label

# # Example usage:
# # single_sample = np.array([...])  # Replace with your single sample data
# # predicted_class = predict_single_sample(model, single_sample)
# # print(f"Predicted Class: {predicted_class}")
