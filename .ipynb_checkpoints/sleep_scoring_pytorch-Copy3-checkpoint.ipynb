# %%
#import packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# from random import randrange, sample
from sklearn.preprocessing import StandardScaler
# from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, accuracy_score
import mne
from pickle import dump, load
import torch
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset, random_split, Subset
import torch.nn as nn
import torch.nn.functional as F
from collections import Counter
import joblib
import time

# %%
EEG_files = ['../../code/LabCode/Fiber_photometry/mouse_807/mouse_807_230511.edf', 
            '../../code/LabCode/Fiber_photometry/mouse_994/mouse_994_230713.edf', 
            '../../code/LabCode/Fiber_photometry/mouse_998/mouse_998_230727.edf', 
            '../../code/LabCode/Fiber_photometry/mouse_1002/mouse_1002_230725.edf',
             '../../code/LabCode/Fiber_photometry/mouse_447/mouse_447_240111.edf',
            '../../code/LabCode/Fiber_photometry/mouse_569/mouse_569_240214.edf',
            '../../code/LabCode/Fiber_photometry/mouse_569/mouse_569_240215.edf',
            '../../code/LabCode/Fiber_photometry/mouse_569/mouse_569_240218.edf',
            '../../code/LabCode/Fiber_photometry/mouse_564/mouse_564_240221.edf',
            '../../code/LabCode/Fiber_photometry/mouse_564/mouse_564_240223.edf',
             '../../code/LabCode/Fiber_photometry/mouse_562/mouse_562_240308.edf',
            '../../code/LabCode/Fiber_photometry/mouse_651/mouse_651_240323.edf',
            '../../code/LabCode/Fiber_photometry/mouse_698/mouse_698_240403.edf',
            '../../code/LabCode/Fiber_photometry/mouse_699/mouse_699_240403.edf',
            '../../code/LabCode/Fiber_photometry/mouse_569/mouse_569_240409.edf',
            '../../code/LabCode/Fiber_photometry/mouse_564/mouse_564_240410.edf',
            '../../code/LabCode/Fiber_photometry/mouse_562/mouse_562_240410.edf',
            '../../code/LabCode/Fiber_photometry/mouse_569/mouse_569_240411.edf',
            '../../code/LabCode/Fiber_photometry/mouse_564/mouse_564_240414.edf',
            '../../code/LabCode/Fiber_photometry/mouse_562/mouse_562_240414.edf',
            '../../code/LabCode/Fiber_photometry/mouse_746/mouse_746_240422.edf',
            '../../code/LabCode/Fiber_photometry/mouse_746/mouse_746_240423.edf', 
            '../../code/LabCode/Fiber_photometry/mouse_746/mouse_746_240513.edf',
            '../../code/LabCode/Fiber_photometry/mouse_746/mouse_746_240515.edf',
            '../../code/LabCode/Fiber_photometry/mouse_564/mouse_564_240520.edf',
            '../../code/LabCode/Fiber_photometry/mouse_562/mouse_562_240520.edf',
            '../../code/LabCode/Fiber_photometry/mouse_562/mouse_562_240521.edf', 
            '../../code/LabCode/Fiber_photometry/mouse_790/mouse_790_240604.edf',
            '../../code/LabCode/Fiber_photometry/mouse_791/mouse_791_240604.edf',
            '../../code/LabCode/Fiber_photometry/mouse_791/mouse_791_240620.edf',
            '../../code/LabCode/Fiber_photometry/mouse_790/mouse_790_240621.edf',
            '../../code/LabCode/Fiber_photometry/mouse_791/mouse_791_240621.edf',
            '../../code/LabCode/Fiber_photometry/mouse_790/mouse_790_240623.edf',
            '../../code/LabCode/Fiber_photometry/mouse_791/mouse_791_240623.edf',
            '../../code/LabCode/Fiber_photometry/mouse_745/mouse_745_240715.edf',
            '../../code/LabCode/Fiber_photometry/mouse_746/mouse_746_240715.edf',
            '../../code/LabCode/Fiber_photometry/mouse_958/mouse_958_240716.edf',
            '../../code/LabCode/Fiber_photometry/mouse_961/mouse_961_240716.edf',
            '../../code/LabCode/Fiber_photometry/mouse_745/mouse_745_240717.edf',
            '../../code/LabCode/Fiber_photometry/mouse_746/mouse_746_240717.edf',
            '../../code/LabCode/Fiber_photometry/mouse_745/mouse_745_240719.edf',
            '../../code/LabCode/Fiber_photometry/mouse_746/mouse_746_240719.edf',
            '../../code/LabCode/Fiber_photometry/mouse_958/mouse_958_240720.edf',
            '../../code/LabCode/Fiber_photometry/mouse_961/mouse_961_240720.edf',
            '../../code/LabCode/Fiber_photometry/mouse_745/mouse_745_240721.edf',
            '../../code/LabCode/Fiber_photometry/mouse_746/mouse_746_240721.edf',
            '../../code/LabCode/Fiber_photometry/mouse_967/mouse_967_240725.edf',
            '../../code/LabCode/Fiber_photometry/mouse_968/mouse_968_240725.edf',
            '../../code/LabCode/Fiber_photometry/mouse_967/mouse_967_240729.edf',
            '../../code/LabCode/Fiber_photometry/mouse_968/mouse_968_240729.edf',
            '../../code/LabCode/Fiber_photometry/mouse_564/mouse_564_240730.edf',
            '../../code/LabCode/Fiber_photometry/mouse_154/mouse_154_240919.edf',
            '../../code/LabCode/Fiber_photometry/mouse_155/mouse_155_240919.edf',      
            '../../code/LabCode/Fiber_photometry/mouse_154/mouse_154_240921.edf',
            '../../code/LabCode/Fiber_photometry/mouse_155/mouse_155_240921.edf',   
            '../../code/LabCode/Fiber_photometry/mouse_154/mouse_154_240923.edf',
            '../../code/LabCode/Fiber_photometry/mouse_155/mouse_155_240923.edf',
            '../../code/LabCode/Fiber_photometry/mouse_154/mouse_154_240925.edf',
            '../../code/LabCode/Fiber_photometry/mouse_155/mouse_155_240925.edf',
            '../../code/LabCode/Fiber_photometry/mouse_136/mouse_136_241004.edf'
            ]
#             '../../code/LabCode/Fiber_photometry/mouse_790/mouse_790_240620.edf',
             
scores_files = ['../../code/LabCode/Fiber_photometry/mouse_807/mouse_807_230511_scores.tsv',
                '../../code/LabCode/Fiber_photometry/mouse_998/mouse_998_230727_scores.tsv', 
                '../../code/LabCode/Fiber_photometry/mouse_994/mouse_994_230713_scores.tsv', 
                '../../code/LabCode/Fiber_photometry/mouse_1002/mouse_1002_230725_scores.tsv',
                '../../code/LabCode/Fiber_photometry/mouse_447/mouse_447_240111_scores.tsv',
               '../../code/LabCode/Fiber_photometry/mouse_569/mouse_569_240214_scores.tsv',
               '../../code/LabCode/Fiber_photometry/mouse_569/mouse_569_240215_scores.tsv',
                '../../code/LabCode/Fiber_photometry/mouse_569/mouse_569_240218_scores.tsv', 
                '../../code/LabCode/Fiber_photometry/mouse_564/mouse_564_240221_scores.tsv',
                '../../code/LabCode/Fiber_photometry/mouse_564/mouse_564_240223_scores.tsv', 
               '../../code/LabCode/Fiber_photometry/mouse_562/mouse_562_240308_scores.tsv',
               '../../code/LabCode/Fiber_photometry/mouse_651/mouse_651_240323_scores.tsv',
               '../../code/LabCode/Fiber_photometry/mouse_698/mouse_698_240403_scores.tsv',
               '../../code/LabCode/Fiber_photometry/mouse_699/mouse_699_240403_scores.tsv',
               '../../code/LabCode/Fiber_photometry/mouse_569/mouse_569_240409_scores.tsv',
               '../../code/LabCode/Fiber_photometry/mouse_564/mouse_564_240410_scores.tsv',
               '../../code/LabCode/Fiber_photometry/mouse_562/mouse_562_240410_scores.tsv',
               '../../code/LabCode/Fiber_photometry/mouse_569/mouse_569_240411_scores.tsv',
               '../../code/LabCode/Fiber_photometry/mouse_564/mouse_564_240414_scores.tsv',
               '../../code/LabCode/Fiber_photometry/mouse_562/mouse_562_240414_scores.tsv',
               '../../code/LabCode/Fiber_photometry/mouse_746/mouse_746_240422_scores.tsv',
               '../../code/LabCode/Fiber_photometry/mouse_746/mouse_746_240423_scores.tsv',
                '../../code/LabCode/Fiber_photometry/mouse_746/mouse_746_240513_scores.tsv', 
                '../../code/LabCode/Fiber_photometry/mouse_746/mouse_746_240515_scores.tsv', 
                '../../code/LabCode/Fiber_photometry/mouse_564/mouse_564_240520_scores.tsv',
                '../../code/LabCode/Fiber_photometry/mouse_562/mouse_562_240520_scores.tsv', 
                '../../code/LabCode/Fiber_photometry/mouse_562/mouse_562_240521_scores.tsv', 
                '../../code/LabCode/Fiber_photometry/mouse_790/mouse_790_240604_scores.tsv', 
                '../../code/LabCode/Fiber_photometry/mouse_791/mouse_791_240604_scores.tsv',
                '../../code/LabCode/Fiber_photometry/mouse_791/mouse_791_240620_scores.tsv', 
                '../../code/LabCode/Fiber_photometry/mouse_790/mouse_790_240621_scores.tsv', 
                '../../code/LabCode/Fiber_photometry/mouse_791/mouse_791_240621_scores.tsv', 
                '../../code/LabCode/Fiber_photometry/mouse_790/mouse_790_240623_scores.tsv', 
                '../../code/LabCode/Fiber_photometry/mouse_791/mouse_791_240623_scores.tsv',
                '../../code/LabCode/Fiber_photometry/mouse_745/mouse_745_240715_scores.tsv', 
                '../../code/LabCode/Fiber_photometry/mouse_746/mouse_746_240715_scores.tsv', 
                '../../code/LabCode/Fiber_photometry/mouse_958/mouse_958_240716_scores.tsv', 
                '../../code/LabCode/Fiber_photometry/mouse_961/mouse_961_240716_scores.tsv', 
                '../../code/LabCode/Fiber_photometry/mouse_745/mouse_745_240717_scores.tsv', 
                '../../code/LabCode/Fiber_photometry/mouse_746/mouse_746_240717_scores.tsv', 
                '../../code/LabCode/Fiber_photometry/mouse_745/mouse_745_240719_scores.tsv', 
                '../../code/LabCode/Fiber_photometry/mouse_746/mouse_746_240719_scores.tsv', 
                '../../code/LabCode/Fiber_photometry/mouse_958/mouse_958_240720_scores.tsv', 
                '../../code/LabCode/Fiber_photometry/mouse_961/mouse_961_240720_scores.tsv', 
                '../../code/LabCode/Fiber_photometry/mouse_745/mouse_745_240721_scores.tsv', 
                '../../code/LabCode/Fiber_photometry/mouse_746/mouse_746_240721_scores.tsv', 
                '../../code/LabCode/Fiber_photometry/mouse_967/mouse_967_240725_scores.tsv', 
                '../../code/LabCode/Fiber_photometry/mouse_968/mouse_968_240725_scores.tsv', 
                '../../code/LabCode/Fiber_photometry/mouse_967/mouse_967_240729_scores.tsv', 
                '../../code/LabCode/Fiber_photometry/mouse_968/mouse_968_240729_scores.tsv', 
                '../../code/LabCode/Fiber_photometry/mouse_564/mouse_564_240730_scores.tsv', 
                '../../code/LabCode/Fiber_photometry/mouse_154/mouse_154_240919_scores.tsv',
                '../../code/LabCode/Fiber_photometry/mouse_155/mouse_155_240919_scores.tsv',      
                '../../code/LabCode/Fiber_photometry/mouse_154/mouse_154_240921_scores.tsv',
                '../../code/LabCode/Fiber_photometry/mouse_155/mouse_155_240921_scores.tsv',   
                '../../code/LabCode/Fiber_photometry/mouse_154/mouse_154_240923_scores.tsv',
                '../../code/LabCode/Fiber_photometry/mouse_155/mouse_155_240923_scores.tsv',
                '../../code/LabCode/Fiber_photometry/mouse_154/mouse_154_240925_scores.tsv',
                '../../code/LabCode/Fiber_photometry/mouse_155/mouse_155_240925_scores.tsv',
                '../../code/LabCode/Fiber_photometry/mouse_136/mouse_136_241004_scores.tsv'
               ]
#                 '../../code/LabCode/Fiber_photometry/mouse_790/mouse_790_240620_scores.tsv',
epoch_limits = 8640
epoch_sum = epoch_limits*len(EEG_files)

# %%
all_data = []
scores_converted = []
for EEG,scores_l in zip(EEG_files,scores_files):
    print(EEG)
    raw = mne.io.read_raw_edf(EEG, preload=True, verbose = False)
    sf = raw.info['sfreq']
    print('Data shape (channels, times) =', raw._data.shape)
    scores = pd.read_csv(scores_l, skiprows=10, delim_whitespace=True)
    scores_array = scores['Time.2']
    for i in range(epoch_limits): 
        all_data.append([raw._data[0][i*1280:(i+1)*1280], raw._data[1][i*1280:(i+1)*1280], raw._data[2][i*1280:(i+1)*1280], raw._data[3][i*1280:(i+1)*1280]]) 
    # in sirenia sleep, 255 unscored, 1 wake, 2 NREM, 3 REM, 4 "parameters"
    # in Yasa -2 = Unscored, -1 = Artefact / Movement, 0 = Wake, 1 = N1 sleep, 2 = N2 sleep, 3 = N3 sleep, 4 = REM sleep
    # for sleep scoring code -2 = Unscored, -1 = Artefact / Movement, 0 = Wake, 1 = N1 sleep, 1 = N2 sleep, 1 = N3 sleep, 2 = REM sleep
        if scores_array[i]==1: # wake
            scores_converted.append(0)
        elif scores_array[i]==2: # NREM
            scores_converted.append(1)
        elif scores_array[i]==3: # REM
            scores_converted.append(2)
        elif scores_array[i]==255: # unscored
            scores_converted.append(-2)      
            print(EEG)
y = np.array(scores_converted).reshape(epoch_sum,1)
data = np.array(all_data)
# Out:
# ../../code/LabCode/Fiber_photometry/mouse_807/mouse_807_230511.edf
# Data shape (channels, times) = (4, 11060224)
# ../../code/LabCode/Fiber_photometry/mouse_994/mouse_994_230713.edf
# Data shape (channels, times) = (4, 11060224)
# ../../code/LabCode/Fiber_photometry/mouse_998/mouse_998_230727.edf
# Data shape (channels, times) = (4, 11060224)
# ../../code/LabCode/Fiber_photometry/mouse_1002/mouse_1002_230725.edf
# Data shape (channels, times) = (4, 11060224)
# ../../code/LabCode/Fiber_photometry/mouse_447/mouse_447_240111.edf
# Data shape (channels, times) = (4, 11060224)
# ../../code/LabCode/Fiber_photometry/mouse_569/mouse_569_240214.edf
# Data shape (channels, times) = (4, 11059200)
# ../../code/LabCode/Fiber_photometry/mouse_569/mouse_569_240215.edf
# Data shape (channels, times) = (4, 11060096)
# ../../code/LabCode/Fiber_photometry/mouse_569/mouse_569_240218.edf
# Data shape (channels, times) = (4, 11060224)
# ../../code/LabCode/Fiber_photometry/mouse_564/mouse_564_240221.edf
# Data shape (channels, times) = (4, 11060096)
# ../../code/LabCode/Fiber_photometry/mouse_564/mouse_564_240223.edf
# Data shape (channels, times) = (4, 11060224)
# ../../code/LabCode/Fiber_photometry/mouse_562/mouse_562_240308.edf
# Data shape (channels, times) = (4, 11060224)
# ../../code/LabCode/Fiber_photometry/mouse_651/mouse_651_240323.edf
# Data shape (channels, times) = (4, 11060224)
# ../../code/LabCode/Fiber_photometry/mouse_698/mouse_698_240403.edf
# Data shape (channels, times) = (4, 11060224)
# ../../code/LabCode/Fiber_photometry/mouse_699/mouse_699_240403.edf
# Data shape (channels, times) = (4, 11060224)
# ../../code/LabCode/Fiber_photometry/mouse_569/mouse_569_240409.edf
# Data shape (channels, times) = (4, 11060096)
# ../../code/LabCode/Fiber_photometry/mouse_564/mouse_564_240410.edf
# Data shape (channels, times) = (4, 11060224)
# ../../code/LabCode/Fiber_photometry/mouse_562/mouse_562_240410.edf
# Data shape (channels, times) = (4, 11060224)
# ../../code/LabCode/Fiber_photometry/mouse_569/mouse_569_240411.edf
# Data shape (channels, times) = (4, 11060224)
# ../../code/LabCode/Fiber_photometry/mouse_564/mouse_564_240414.edf
# Data shape (channels, times) = (4, 11060224)
# ../../code/LabCode/Fiber_photometry/mouse_562/mouse_562_240414.edf
# Data shape (channels, times) = (4, 11060224)
# ../../code/LabCode/Fiber_photometry/mouse_746/mouse_746_240422.edf
# Data shape (channels, times) = (4, 11060096)
# ../../code/LabCode/Fiber_photometry/mouse_746/mouse_746_240423.edf
# Data shape (channels, times) = (4, 11060224)
# ../../code/LabCode/Fiber_photometry/mouse_746/mouse_746_240513.edf
# Data shape (channels, times) = (4, 11060096)
# ../../code/LabCode/Fiber_photometry/mouse_746/mouse_746_240515.edf
# Data shape (channels, times) = (4, 11060224)
# ../../code/LabCode/Fiber_photometry/mouse_564/mouse_564_240520.edf
# Data shape (channels, times) = (4, 11060096)
# ../../code/LabCode/Fiber_photometry/mouse_562/mouse_562_240520.edf
# Data shape (channels, times) = (4, 11060096)
# ../../code/LabCode/Fiber_photometry/mouse_562/mouse_562_240521.edf
# Data shape (channels, times) = (4, 11060224)
# ../../code/LabCode/Fiber_photometry/mouse_790/mouse_790_240604.edf
# Data shape (channels, times) = (4, 11060224)
# ../../code/LabCode/Fiber_photometry/mouse_791/mouse_791_240604.edf
# Data shape (channels, times) = (4, 11060224)
# ../../code/LabCode/Fiber_photometry/mouse_791/mouse_791_240620.edf
# Data shape (channels, times) = (4, 11060224)
# ../../code/LabCode/Fiber_photometry/mouse_790/mouse_790_240621.edf
# Data shape (channels, times) = (4, 11060224)
# ../../code/LabCode/Fiber_photometry/mouse_791/mouse_791_240621.edf
# Data shape (channels, times) = (4, 11060224)
# ../../code/LabCode/Fiber_photometry/mouse_790/mouse_790_240623.edf
# Data shape (channels, times) = (4, 11060224)
# ../../code/LabCode/Fiber_photometry/mouse_791/mouse_791_240623.edf
# Data shape (channels, times) = (4, 11060224)
# ../../code/LabCode/Fiber_photometry/mouse_745/mouse_745_240715.edf
# Data shape (channels, times) = (4, 11060224)
# ../../code/LabCode/Fiber_photometry/mouse_746/mouse_746_240715.edf
# Data shape (channels, times) = (4, 11060224)
# ../../code/LabCode/Fiber_photometry/mouse_958/mouse_958_240716.edf
# Data shape (channels, times) = (4, 11060224)
# ../../code/LabCode/Fiber_photometry/mouse_961/mouse_961_240716.edf
# Data shape (channels, times) = (4, 11060224)
# ../../code/LabCode/Fiber_photometry/mouse_745/mouse_745_240717.edf
# Data shape (channels, times) = (4, 11060224)
# ../../code/LabCode/Fiber_photometry/mouse_746/mouse_746_240717.edf
# Data shape (channels, times) = (4, 11060224)
# ../../code/LabCode/Fiber_photometry/mouse_745/mouse_745_240719.edf
# Data shape (channels, times) = (4, 11060224)
# ../../code/LabCode/Fiber_photometry/mouse_746/mouse_746_240719.edf
# Data shape (channels, times) = (4, 11060224)
# ../../code/LabCode/Fiber_photometry/mouse_958/mouse_958_240720.edf
# Data shape (channels, times) = (4, 11060096)
# ../../code/LabCode/Fiber_photometry/mouse_961/mouse_961_240720.edf
# Data shape (channels, times) = (4, 11060096)
# ../../code/LabCode/Fiber_photometry/mouse_745/mouse_745_240721.edf
# Data shape (channels, times) = (4, 11060224)
# ../../code/LabCode/Fiber_photometry/mouse_746/mouse_746_240721.edf
# Data shape (channels, times) = (4, 11060224)
# ../../code/LabCode/Fiber_photometry/mouse_967/mouse_967_240725.edf
# Data shape (channels, times) = (4, 11060224)
# ../../code/LabCode/Fiber_photometry/mouse_968/mouse_968_240725.edf
# Data shape (channels, times) = (4, 11060224)
# ../../code/LabCode/Fiber_photometry/mouse_967/mouse_967_240729.edf
# Data shape (channels, times) = (4, 11060224)
# ../../code/LabCode/Fiber_photometry/mouse_968/mouse_968_240729.edf
# Data shape (channels, times) = (4, 11060224)
# ../../code/LabCode/Fiber_photometry/mouse_564/mouse_564_240730.edf
# Data shape (channels, times) = (4, 11060224)
# ../../code/LabCode/Fiber_photometry/mouse_154/mouse_154_240919.edf
# Data shape (channels, times) = (4, 11060224)
# ../../code/LabCode/Fiber_photometry/mouse_155/mouse_155_240919.edf
# Data shape (channels, times) = (4, 11060224)
# ../../code/LabCode/Fiber_photometry/mouse_154/mouse_154_240921.edf
# Data shape (channels, times) = (4, 11060224)
# ../../code/LabCode/Fiber_photometry/mouse_155/mouse_155_240921.edf
# Data shape (channels, times) = (4, 11060224)
# ../../code/LabCode/Fiber_photometry/mouse_154/mouse_154_240923.edf
# Data shape (channels, times) = (4, 11060224)
# ../../code/LabCode/Fiber_photometry/mouse_155/mouse_155_240923.edf
# Data shape (channels, times) = (4, 11060224)
# ../../code/LabCode/Fiber_photometry/mouse_154/mouse_154_240925.edf
# Data shape (channels, times) = (4, 11060224)
# ../../code/LabCode/Fiber_photometry/mouse_155/mouse_155_240925.edf
# Data shape (channels, times) = (4, 11060224)
# ../../code/LabCode/Fiber_photometry/mouse_136/mouse_136_241004.edf
# Data shape (channels, times) = (4, 11060224)

# %%
np.unique(y)
# Out:
# array([0, 1, 2])

# %%
scaler_CH1 = StandardScaler().fit(data[:,0,:])
scaler_CH2 = StandardScaler().fit(data[:,1,:])
scaler_CH3 = StandardScaler().fit(data[:,2,:])

data_CH1_normalized = scaler_CH1.transform(data[:, 0, :])
data_CH2_normalized = scaler_CH2.transform(data[:, 1, :])
data_CH3_normalized = scaler_CH3.transform(data[:, 2, :])

X = np.stack((data_CH1_normalized,data_CH2_normalized,data_CH3_normalized),axis=1)

# %%
joblib.dump(scaler_CH1, 'scaler_CH1_240513.pkl')
joblib.dump(scaler_CH2, 'scaler_CH2_240513.pkl')
joblib.dump(scaler_CH3, 'scaler_CH3_240513.pkl')

# %%
num_mouse = len(EEG_files)
# Convert your data to tensors
X_tensor = torch.tensor(X, dtype=torch.float32)
y_tensor = torch.tensor(y, dtype=torch.long).squeeze()

# Create a list to hold datasets for each mouse
datasets = []

# Calculate the number of epochs per third of mouse recording 
epochs_per_thirdmouse = X.shape[0] // (num_mouse*3) # 8640

# Split data by mouse
for i in range(num_mouse*3):
    start_idx = i * epochs_per_thirdmouse
    end_idx = start_idx + epochs_per_thirdmouse
    thirdmouse_dataset = TensorDataset(X_tensor[start_idx:end_idx], y_tensor[start_idx:end_idx])
    datasets.append(thirdmouse_dataset)

# %%
# Split each mouse's data into training, validation, and test sets
train_datasets = []
val_datasets = []
test_datasets = []

for mouse_dataset in datasets:
    # Define the sizes for training, validation, and test sets (e.g., 70%, 15%, 15%)
    train_size = int(0.7 * len(mouse_dataset))
    val_size = int(0.15 * len(mouse_dataset))
    test_size = len(mouse_dataset) - train_size - val_size
    # Split the dataset
    train_data = torch.utils.data.Subset(mouse_dataset, range(train_size))
    val_data = torch.utils.data.Subset(mouse_dataset, range(train_size, train_size + val_size))
    test_data = torch.utils.data.Subset(mouse_dataset, range(train_size + val_size, len(mouse_dataset)))

#     train_data, val_data, test_data = random_split(mouse_dataset, [train_size, val_size, test_size])
    
    # Append to the lists
    train_datasets.append(train_data)
    val_datasets.append(val_data)
    test_datasets.append(test_data)

# Concatenate datasets from all mice to create the final training, validation, and test sets
train_dataset = torch.utils.data.ConcatDataset(train_datasets)
val_dataset = torch.utils.data.ConcatDataset(val_datasets)
test_dataset = torch.utils.data.ConcatDataset(test_datasets)

# %%
# Create data loaders
batch_size = 256
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=False)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %%
# Check for GPU availability
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

class SleepScoringModel(nn.Module):
    def __init__(self, dropout_rate=0.5, weight_decay=1e-4):
        super(SleepScoringModel, self).__init__()
        
        self.conv1 = nn.Conv1d(3, 32, kernel_size=3, stride=1, padding=1)
        self.conv2 = nn.Conv1d(32, 64, kernel_size=3, stride=1, padding=1)
        
        # Add dropout layers
        self.dropout1 = nn.Dropout(dropout_rate)
        self.dropout2 = nn.Dropout(dropout_rate)
        
        self.fc1 = nn.Linear(64 * 1280, 128)
        self.fc2 = nn.Linear(128, 3)
        
        # Add weight decay to the optimizer (e.g., Adam)
        self.weight_decay = weight_decay

    def forward(self, x):
        x = self.conv1(x)
        x = F.relu(x)
        x = self.dropout1(x)  # Apply dropout
        x = self.conv2(x)
        x = F.relu(x)
        x = self.dropout2(x)  # Apply dropout
        x = x.view(x.size(0), -1)
        x = self.fc1(x)
        x = F.relu(x)
        x = self.fc2(x)
        return x

# Create an instance of the model
model = SleepScoringModel().to(device)

# %%
class_occurrence = Counter()
for _, labels in train_loader:
    # Assuming labels is a tensor containing class labels
    class_occurrence.update(labels.numpy())

# Print the class occurrences
print("Class Occurrences:", class_occurrence)
class_occurences = [class_occurrence[0],class_occurrence[1],class_occurrence[2]]
print(class_occurences)

# %%
# Step 2: Define the Loss Function and Optimizer
total_samples = len(train_dataset)
class_counts = []
for i in class_occurences:
    class_counts.append(i/total_samples)
class_weights = 1.0 / torch.tensor(class_counts)
print(class_weights)
class_weights = class_weights.to(device)

# %%
criterion = nn.CrossEntropyLoss(weight=class_weights)
optimizer = optim.Adam(model.parameters(), lr=0.0003, weight_decay=model.weight_decay)

# %%
# Initialize variables for early stopping
best_val_loss = float('inf')  # Initialize the best validation loss to infinity
patience = 5  # Number of epochs without improvement
no_improve_epochs = 0  # Initialize the count of epochs without improvement

# Initialize empty lists to store training and validation loss and accuracy values
train_losses = []
train_accuracies = []
val_losses = []
val_accuracies = []

# Training Loop
num_epochs = 100

for epoch in range(num_epochs):
    model.train()  # Set the model to training mode
    correct = 0
    total = 0
    running_loss = 0.0
    
    for batch_X, batch_y in train_loader:
        batch_X, batch_y = batch_X.to(device), batch_y.to(device)
        optimizer.zero_grad()
        outputs = model(batch_X)
        loss = criterion(outputs, batch_y.squeeze())
        loss.backward()
        optimizer.step()
        
        # Compute accuracy for the batch
        _, predicted = torch.max(outputs.data, 1)
        total += batch_y.size(0)
        correct += (predicted == batch_y.squeeze()).sum().item()
        
        running_loss += loss.item() * batch_X.size(0)
    
    epoch_loss = running_loss / len(train_loader.dataset)
    epoch_accuracy = correct / total
    
    train_losses.append(epoch_loss)
    train_accuracies.append(epoch_accuracy)
    
    print(f"Epoch [{epoch+1}/{num_epochs}], Training Loss: {epoch_loss:.4f}, Training Accuracy: {epoch_accuracy:.4f}")

    # Validation Evaluation
    model.eval()  # Set the model to evaluation mode
    correct_val = 0
    total_val = 0
    running_loss_val = 0.0
    all_pred_labels = []
    all_true_labels = []
    
    with torch.no_grad():  # Disable gradient computation for validation
        for batch_X_val, batch_y_val in val_loader:
            batch_X_val, batch_y_val = batch_X_val.to(device), batch_y_val.to(device)
            outputs_val = model(batch_X_val)
            loss_val = criterion(outputs_val, batch_y_val.squeeze())
            
            # Compute accuracy for the validation batch
            _, predicted_val = torch.max(outputs_val.data, 1)
            total_val += batch_y_val.size(0)
            correct_val += (predicted_val == batch_y_val.squeeze()).sum().item()
            
            running_loss_val += loss_val.item() * batch_X_val.size(0)
            all_pred_labels.extend(predicted_val.cpu().numpy())
            all_true_labels.extend(batch_y_val.cpu().numpy())
            
    epoch_loss_val = running_loss_val / len(val_loader.dataset)
    epoch_accuracy_val = correct_val / total_val
    
    val_losses.append(epoch_loss_val)
    val_accuracies.append(epoch_accuracy_val)
    
    # Compute the confusion matrix
    conf_matrix = confusion_matrix(all_true_labels, all_pred_labels)

    # Calculate class-wise accuracy
    class_accuracy = conf_matrix.diagonal() / conf_matrix.sum(axis=1)
    
    print(f"Validation Loss: {epoch_loss_val:.4f}, Validation Accuracy: {epoch_accuracy_val:.4f}")
    for i, accuracy in enumerate(class_accuracy):
        print(f"Class {i}: Accuracy = {accuracy:.4f}")


#     # Check for early stopping based on validation loss
#     if epoch_loss_val < best_val_loss:
#         best_val_loss = epoch_loss_val  # Update the best validation loss
#         no_improve_epochs = 0  # Reset the count of epochs without improvement
#     else:
#         no_improve_epochs += 1  # Increment the count of epochs without improvement

#     # If no improvement for 'patience' epochs, stop training
#     if no_improve_epochs >= patience:
#         print(f"Early stopping after {epoch+1} epochs without improvement.")
#         break

# %%
# Plot the training and validation loss
plt.figure(figsize=(10, 4))
plt.subplot(1, 2, 1)
plt.plot(train_losses, label='Training Loss')
plt.plot(val_losses, label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()

# Plot the training and validation accuracy
plt.subplot(1, 2, 2)
plt.plot(train_accuracies, label='Training Accuracy')
plt.plot(val_accuracies, label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Plotting Loss and Accuracy
plt.figure(figsize=(12, 4))

# Plot Training Loss
plt.subplot(1, 2, 1)
plt.plot(train_losses, label='Training Loss')
plt.plot(val_losses, label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
# plt.ylim([0,5])
plt.legend()

# Plot Training Accuracy
plt.subplot(1, 2, 2)
plt.plot(train_accuracies, label='Training Accuracy', color='r')
plt.plot(val_accuracies, label='Validation Accuracy', color='g')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')

plt.legend()

plt.tight_layout()
plt.show()

# %%
# Set the model to evaluation mode
model.eval()

# Initialize lists to store predicted and true labels
all_pred_labels = []
all_true_labels = []

# Iterate through the testing DataLoader
with torch.no_grad():  # Disable gradient computation for inference
    for batch_X_test, batch_y_test in test_loader:
        # Move the batch of data and labels to the device
        batch_X_test, batch_y_test = batch_X_test.to(device), batch_y_test.to(device)
        
        # Perform a forward pass through the model
        outputs_test = model(batch_X_test)
        
        # Compute the predicted labels
        _, predicted_test = torch.max(outputs_test, 1)
        
        # Accumulate the predicted labels and true labels
        all_pred_labels.extend(predicted_test.cpu().numpy())
        all_true_labels.extend(batch_y_test.cpu().numpy())

# Convert lists to NumPy arrays for further analysis
all_pred_labels = np.array(all_pred_labels)
all_true_labels = np.array(all_true_labels)

# Compute overall accuracy
accuracy_overall = accuracy_score(all_true_labels, all_pred_labels)
print(f"Overall Testing Accuracy: {accuracy_overall:.4f}")

# Compute class-wise accuracy
for i in range(3):  # Assuming 3 classes (wake, NREM, REM)
    class_accuracy = accuracy_score(all_true_labels == i, all_pred_labels == i)
    print(f"Class {i} Accuracy: {class_accuracy:.4f}")
# Out:
# Overall Testing Accuracy: 0.8222
# Class 0 Accuracy: 0.8396
# Class 1 Accuracy: 0.8498
# Class 2 Accuracy: 0.9549

# %%
# def initialize_model(model):
#     # Initialize model parameters here
#     for param in model.parameters():
#         if param.requires_grad:
#             nn.init.xavier_uniform_(param.data)
# initialize_model(model)

# %%
# # Define the file path to save the model
# model_path = 'sleep_scoring_model_241022.pth'

# # Save the model's state_dict to the file path
# torch.save(model.state_dict(), model_path)

# print(f"Model saved to {model_path}")
# Out:
# Model saved to sleep_scoring_model_241022.pth

# %%
# # Define the file path to load the model
# model_path = 'sleep_scoring_model_240.pth'

# # Initialize a new model instance with the same architecture
# model = SleepScoringModel().to(device)

# # Load the model's state_dict from the file path
# model.load_state_dict(torch.load(model_path, map_location=device))

# print(f"Model loaded from {model_path}")

# %%
mouse_str1 = 'mouse_154' 
date_str = '240921'
root = 'D:\Makinson_lab\code\LabCode\Fiber_photometry'
raw = mne.io.read_raw_edf(root + '/'+ mouse_str1+'/'+mouse_str1+'_'+date_str+'.edf')
# Out:
# Extracting EDF parameters from D:\Makinson_lab\code\LabCode\Fiber_photometry\mouse_154\mouse_154_240921.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

class SleepScoringModel(nn.Module):
    def __init__(self, dropout_rate=0.5, weight_decay=1e-4):
        super(SleepScoringModel, self).__init__()

        self.conv1 = nn.Conv1d(4, 32, kernel_size=3, stride=1, padding=1)
        self.conv2 = nn.Conv1d(32, 64, kernel_size=3, stride=1, padding=1)

        # Add dropout layers
        self.dropout1 = nn.Dropout(dropout_rate)
        self.dropout2 = nn.Dropout(dropout_rate)

        self.fc1 = nn.Linear(64 * 1280, 128)
        self.fc2 = nn.Linear(128, 3)

        # Add weight decay to the optimizer (e.g., Adam)
        self.weight_decay = weight_decay

    def forward(self, x):
        x = self.conv1(x)
        x = F.relu(x)
        x = self.dropout1(x)  # Apply dropout
        x = self.conv2(x)
        x = F.relu(x)
        x = self.dropout2(x)  # Apply dropout
        x = x.view(x.size(0), -1)
        x = self.fc1(x)
        x = F.relu(x)
        x = self.fc2(x)
        return x

model_path = 'sleep_scoring_model_241022.pth'
model = SleepScoringModel().to(device)
model.load_state_dict(torch.load(model_path, map_location=device))
print(f"Model loaded from {model_path}")

scaler_CH1 = joblib.load('scaler_CH1_241022.pkl')
scaler_CH2 = joblib.load('scaler_CH2_241022.pkl')
scaler_CH3 = joblib.load('scaler_CH3_241022.pkl')
scaler_CH4 = joblib.load('scaler_CH3_241022.pkl')
scores = []
for i in range(8640):
    start_time = time.time() 
    
    CH1 = raw[0][0][0][1280*i:1280*(i+1)]
    CH2 = raw[1][0][0][1280*i:1280*(i+1)]
    CH3 = raw[2][0][0][1280*i:1280*(i+1)]
    CH4 = raw[3][0][0][1280*i:1280*(i+1)]
    scaled_CH1 = scaler_CH1.transform(CH1.reshape(1,1280))
    scaled_CH2 = scaler_CH2.transform(CH2.reshape(1,1280))
    scaled_CH3 = scaler_CH3.transform(CH3.reshape(1,1280))
    scaled_CH4 = scaler_CH4.transform(CH4.reshape(1,1280))
    X_data = np.vstack([scaled_CH1,scaled_CH2,scaled_CH3,scaled_CH4])
    tensor_sample = torch.tensor(X_data, dtype=torch.float32).unsqueeze(0).to(device)
    model.eval()
    with torch.no_grad():  # Disable gradient computation for inference
        outputs = model(tensor_sample)
    _, predicted_label = torch.max(outputs, 1)
    y_hat = predicted_label.item()
    scores.append(y_hat)
    batch_time = time.time() - start_time
    percentage_complete = (i / 8640) * 100
    print(f"Processed chunk {i}/{8640} "
      f"({percentage_complete:.2f}% complete) - Time per batch: {batch_time:.2f} seconds")
# Out:
# Model loaded from sleep_scoring_model_241022.pth
# Processed chunk 0/8640 (0.00% complete) - Time per batch: 0.80 seconds
# Processed chunk 1/8640 (0.01% complete) - Time per batch: 0.67 seconds
# Processed chunk 2/8640 (0.02% complete) - Time per batch: 0.69 seconds
# Processed chunk 3/8640 (0.03% complete) - Time per batch: 0.63 seconds
# Processed chunk 4/8640 (0.05% complete) - Time per batch: 0.66 seconds
# Processed chunk 5/8640 (0.06% complete) - Time per batch: 0.63 seconds
# Processed chunk 6/8640 (0.07% complete) - Time per batch: 0.63 seconds
# Processed chunk 7/8640 (0.08% complete) - Time per batch: 0.67 seconds
# Processed chunk 8/8640 (0.09% complete) - Time per batch: 0.65 seconds
# Processed chunk 9/8640 (0.10% complete) - Time per batch: 0.66 seconds
# Processed chunk 10/8640 (0.12% complete) - Time per batch: 0.70 seconds
# Processed chunk 11/8640 (0.13% complete) - Time per batch: 0.64 seconds
# Processed chunk 12/8640 (0.14% complete) - Time per batch: 0.56 seconds
# Processed chunk 13/8640 (0.15% complete) - Time per batch: 0.58 seconds
# Processed chunk 14/8640 (0.16% complete) - Time per batch: 0.62 seconds
# Processed chunk 15/8640 (0.17% complete) - Time per batch: 0.69 seconds
# Processed chunk 16/8640 (0.19% complete) - Time per batch: 0.70 seconds
# Processed chunk 17/8640 (0.20% complete) - Time per batch: 0.63 seconds
# Processed chunk 18/8640 (0.21% complete) - Time per batch: 0.66 seconds
# Processed chunk 19/8640 (0.22% complete) - Time per batch: 0.66 seconds
# Processed chunk 20/8640 (0.23% complete) - Time per batch: 0.64 seconds
# Processed chunk 21/8640 (0.24% complete) - Time per batch: 0.65 seconds
# Processed chunk 22/8640 (0.25% complete) - Time per batch: 0.65 seconds
# Processed chunk 23/8640 (0.27% complete) - Time per batch: 0.65 seconds
# Processed chunk 24/8640 (0.28% complete) - Time per batch: 0.66 seconds
# Processed chunk 25/8640 (0.29% complete) - Time per batch: 0.68 seconds
# Processed chunk 26/8640 (0.30% complete) - Time per batch: 0.64 seconds
# Processed chunk 27/8640 (0.31% complete) - Time per batch: 0.66 seconds
# Processed chunk 28/8640 (0.32% complete) - Time per batch: 0.67 seconds
# Processed chunk 29/8640 (0.34% complete) - Time per batch: 0.65 seconds
# Processed chunk 30/8640 (0.35% complete) - Time per batch: 0.66 seconds
# Processed chunk 31/8640 (0.36% complete) - Time per batch: 0.62 seconds
# Processed chunk 32/8640 (0.37% complete) - Time per batch: 0.68 seconds
# Processed chunk 33/8640 (0.38% complete) - Time per batch: 0.66 seconds
# Processed chunk 34/8640 (0.39% complete) - Time per batch: 0.64 seconds
# Processed chunk 35/8640 (0.41% complete) - Time per batch: 0.65 seconds
# Processed chunk 36/8640 (0.42% complete) - Time per batch: 0.64 seconds
# Processed chunk 37/8640 (0.43% complete) - Time per batch: 0.64 seconds
# Processed chunk 38/8640 (0.44% complete) - Time per batch: 0.66 seconds
# Processed chunk 39/8640 (0.45% complete) - Time per batch: 0.65 seconds
# Processed chunk 40/8640 (0.46% complete) - Time per batch: 0.63 seconds
# Processed chunk 41/8640 (0.47% complete) - Time per batch: 0.70 seconds
# Processed chunk 42/8640 (0.49% complete) - Time per batch: 0.70 seconds
# Processed chunk 43/8640 (0.50% complete) - Time per batch: 0.64 seconds
# Processed chunk 44/8640 (0.51% complete) - Time per batch: 0.67 seconds
# Processed chunk 45/8640 (0.52% complete) - Time per batch: 0.67 seconds
# Processed chunk 46/8640 (0.53% complete) - Time per batch: 0.62 seconds
# Processed chunk 47/8640 (0.54% complete) - Time per batch: 0.69 seconds
# Processed chunk 48/8640 (0.56% complete) - Time per batch: 0.65 seconds
# Processed chunk 49/8640 (0.57% complete) - Time per batch: 0.62 seconds
# Processed chunk 50/8640 (0.58% complete) - Time per batch: 0.67 seconds
# Processed chunk 51/8640 (0.59% complete) - Time per batch: 0.66 seconds
# Processed chunk 52/8640 (0.60% complete) - Time per batch: 0.62 seconds
# Processed chunk 53/8640 (0.61% complete) - Time per batch: 0.69 seconds
# Processed chunk 54/8640 (0.62% complete) - Time per batch: 0.67 seconds
# Processed chunk 55/8640 (0.64% complete) - Time per batch: 0.63 seconds
# Processed chunk 56/8640 (0.65% complete) - Time per batch: 0.70 seconds
# Processed chunk 57/8640 (0.66% complete) - Time per batch: 0.65 seconds
# Processed chunk 58/8640 (0.67% complete) - Time per batch: 0.63 seconds
# Processed chunk 59/8640 (0.68% complete) - Time per batch: 0.67 seconds
# Processed chunk 60/8640 (0.69% complete) - Time per batch: 0.74 seconds
# Processed chunk 61/8640 (0.71% complete) - Time per batch: 0.64 seconds
# Processed chunk 62/8640 (0.72% complete) - Time per batch: 0.67 seconds
# Processed chunk 63/8640 (0.73% complete) - Time per batch: 0.64 seconds
# Processed chunk 64/8640 (0.74% complete) - Time per batch: 0.62 seconds
# Processed chunk 65/8640 (0.75% complete) - Time per batch: 0.67 seconds
# Processed chunk 66/8640 (0.76% complete) - Time per batch: 0.66 seconds
# Processed chunk 67/8640 (0.78% complete) - Time per batch: 0.73 seconds
# Processed chunk 68/8640 (0.79% complete) - Time per batch: 0.78 seconds
# Processed chunk 69/8640 (0.80% complete) - Time per batch: 0.79 seconds
# Processed chunk 70/8640 (0.81% complete) - Time per batch: 0.79 seconds
# Processed chunk 71/8640 (0.82% complete) - Time per batch: 0.71 seconds
# Processed chunk 72/8640 (0.83% complete) - Time per batch: 0.69 seconds
# Processed chunk 73/8640 (0.84% complete) - Time per batch: 0.68 seconds
# Processed chunk 74/8640 (0.86% complete) - Time per batch: 0.63 seconds
# Processed chunk 75/8640 (0.87% complete) - Time per batch: 0.67 seconds
# Processed chunk 76/8640 (0.88% complete) - Time per batch: 0.69 seconds
# Processed chunk 77/8640 (0.89% complete) - Time per batch: 0.63 seconds
# Processed chunk 78/8640 (0.90% complete) - Time per batch: 0.67 seconds
# Processed chunk 79/8640 (0.91% complete) - Time per batch: 0.69 seconds
# Processed chunk 80/8640 (0.93% complete) - Time per batch: 0.62 seconds
# Processed chunk 81/8640 (0.94% complete) - Time per batch: 0.67 seconds
# Processed chunk 82/8640 (0.95% complete) - Time per batch: 0.64 seconds
# Processed chunk 83/8640 (0.96% complete) - Time per batch: 0.64 seconds
# Processed chunk 84/8640 (0.97% complete) - Time per batch: 0.63 seconds
# Processed chunk 85/8640 (0.98% complete) - Time per batch: 0.66 seconds
# Processed chunk 86/8640 (1.00% complete) - Time per batch: 0.64 seconds
# Processed chunk 87/8640 (1.01% complete) - Time per batch: 0.69 seconds
# Processed chunk 88/8640 (1.02% complete) - Time per batch: 0.67 seconds
# Processed chunk 89/8640 (1.03% complete) - Time per batch: 0.64 seconds
# Processed chunk 90/8640 (1.04% complete) - Time per batch: 0.66 seconds
# Processed chunk 91/8640 (1.05% complete) - Time per batch: 0.65 seconds
# Processed chunk 92/8640 (1.06% complete) - Time per batch: 0.64 seconds
# Processed chunk 93/8640 (1.08% complete) - Time per batch: 0.64 seconds
# Processed chunk 94/8640 (1.09% complete) - Time per batch: 0.63 seconds
# Processed chunk 95/8640 (1.10% complete) - Time per batch: 0.66 seconds
# Processed chunk 96/8640 (1.11% complete) - Time per batch: 0.66 seconds
# Processed chunk 97/8640 (1.12% complete) - Time per batch: 0.63 seconds
# Processed chunk 98/8640 (1.13% complete) - Time per batch: 0.67 seconds
# Processed chunk 99/8640 (1.15% complete) - Time per batch: 0.80 seconds
# Processed chunk 100/8640 (1.16% complete) - Time per batch: 0.64 seconds
# Processed chunk 101/8640 (1.17% complete) - Time per batch: 0.64 seconds
# Processed chunk 102/8640 (1.18% complete) - Time per batch: 0.64 seconds
# Processed chunk 103/8640 (1.19% complete) - Time per batch: 0.63 seconds
# Processed chunk 104/8640 (1.20% complete) - Time per batch: 0.70 seconds
# Processed chunk 105/8640 (1.22% complete) - Time per batch: 0.64 seconds
# Processed chunk 106/8640 (1.23% complete) - Time per batch: 0.62 seconds
# Processed chunk 107/8640 (1.24% complete) - Time per batch: 0.68 seconds
# Processed chunk 108/8640 (1.25% complete) - Time per batch: 0.66 seconds
# Processed chunk 109/8640 (1.26% complete) - Time per batch: 0.63 seconds
# Processed chunk 110/8640 (1.27% complete) - Time per batch: 0.67 seconds
# Processed chunk 111/8640 (1.28% complete) - Time per batch: 0.69 seconds
# Processed chunk 112/8640 (1.30% complete) - Time per batch: 0.63 seconds
# Processed chunk 113/8640 (1.31% complete) - Time per batch: 0.69 seconds
# Processed chunk 114/8640 (1.32% complete) - Time per batch: 0.68 seconds
# Processed chunk 115/8640 (1.33% complete) - Time per batch: 0.64 seconds
# Processed chunk 116/8640 (1.34% complete) - Time per batch: 0.69 seconds
# Processed chunk 117/8640 (1.35% complete) - Time per batch: 0.66 seconds
# Processed chunk 118/8640 (1.37% complete) - Time per batch: 0.64 seconds
# Processed chunk 119/8640 (1.38% complete) - Time per batch: 0.69 seconds
# Processed chunk 120/8640 (1.39% complete) - Time per batch: 0.71 seconds
# Processed chunk 121/8640 (1.40% complete) - Time per batch: 0.66 seconds
# Processed chunk 122/8640 (1.41% complete) - Time per batch: 0.69 seconds
# Processed chunk 123/8640 (1.42% complete) - Time per batch: 0.67 seconds
# Processed chunk 124/8640 (1.44% complete) - Time per batch: 0.64 seconds
# Processed chunk 125/8640 (1.45% complete) - Time per batch: 0.68 seconds
# Processed chunk 126/8640 (1.46% complete) - Time per batch: 0.69 seconds
# Processed chunk 127/8640 (1.47% complete) - Time per batch: 0.66 seconds
# Processed chunk 128/8640 (1.48% complete) - Time per batch: 0.70 seconds
# Processed chunk 129/8640 (1.49% complete) - Time per batch: 0.71 seconds
# Processed chunk 130/8640 (1.50% complete) - Time per batch: 0.70 seconds
# Processed chunk 131/8640 (1.52% complete) - Time per batch: 0.68 seconds
# Processed chunk 132/8640 (1.53% complete) - Time per batch: 0.68 seconds
# Processed chunk 133/8640 (1.54% complete) - Time per batch: 0.69 seconds
# Processed chunk 134/8640 (1.55% complete) - Time per batch: 0.67 seconds
# Processed chunk 135/8640 (1.56% complete) - Time per batch: 0.69 seconds
# Processed chunk 136/8640 (1.57% complete) - Time per batch: 0.68 seconds
# Processed chunk 137/8640 (1.59% complete) - Time per batch: 0.67 seconds
# Processed chunk 138/8640 (1.60% complete) - Time per batch: 0.69 seconds

# %%
# Set up the device (GPU if available)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Define the neural network model
class SleepScoringModel(nn.Module):
    def __init__(self, dropout_rate=0.5, weight_decay=1e-4):
        super(SleepScoringModel, self).__init__()

        self.conv1 = nn.Conv1d(4, 32, kernel_size=3, stride=1, padding=1)
        self.conv2 = nn.Conv1d(32, 64, kernel_size=3, stride=1, padding=1)

        self.dropout1 = nn.Dropout(dropout_rate)
        self.dropout2 = nn.Dropout(dropout_rate)

        self.fc1 = nn.Linear(64 * 1280, 128)
        self.fc2 = nn.Linear(128, 3)

        self.weight_decay = weight_decay

    def forward(self, x):
        x = self.conv1(x)
        x = F.relu(x)
        x = self.dropout1(x)  # Apply dropout
        x = self.conv2(x)
        x = F.relu(x)
        x = self.dropout2(x)  # Apply dropout
        x = x.view(x.size(0), -1)
        x = self.fc1(x)
        x = F.relu(x)
        x = self.fc2(x)
        return x

# Load the model and scalers
model_path = 'sleep_scoring_model_241022.pth'
model = SleepScoringModel().to(device)
model.load_state_dict(torch.load(model_path, map_location=device))
model.eval()  # Set model to evaluation mode
print(f"Model loaded from {model_path}")
if next(model.parameters()).is_cuda:
    print("Model is using the GPU.")
else:
    print("Model is using the CPU.")

scaler_CH1 = joblib.load('scaler_CH1_241022.pkl')
scaler_CH2 = joblib.load('scaler_CH2_241022.pkl')
scaler_CH3 = joblib.load('scaler_CH3_241022.pkl')
scaler_CH4 = joblib.load('scaler_CH3_241022.pkl')
# Out:
# Model loaded from sleep_scoring_model_241022.pth
# Model is using the GPU.

# %%
# Parameters for batching
batch_size = 16  # Adjust this based on your GPU memory
scores = []

# Process data in batches with a progress tracker
total_batches = (8640 + batch_size - 1) // batch_size  # Total number of batches

for batch_idx in range(0, 8640, batch_size):
    start_time = time.time()  # Start timer for the batch
    
    # Prepare batch data
    CH1_batch = [raw[0][0][0][1280 * j:1280 * (j + 1)] for j in range(batch_idx, min(batch_idx + batch_size, 8640))]
    CH2_batch = [raw[1][0][0][1280 * j:1280 * (j + 1)] for j in range(batch_idx, min(batch_idx + batch_size, 8640))]
    CH3_batch = [raw[2][0][0][1280 * j:1280 * (j + 1)] for j in range(batch_idx, min(batch_idx + batch_size, 8640))]
    CH4_batch = [raw[3][0][0][1280 * j:1280 * (j + 1)] for j in range(batch_idx, min(batch_idx + batch_size, 8640))]

    # Scale the data
    X_data_batch = np.stack([
        [scaler_CH1.transform(CH1.reshape(1, 1280))[0],
         scaler_CH2.transform(CH2.reshape(1, 1280))[0],
         scaler_CH3.transform(CH3.reshape(1, 1280))[0],
         scaler_CH4.transform(CH4.reshape(1, 1280))[0]]
        for CH1, CH2, CH3, CH4 in zip(CH1_batch, CH2_batch, CH3_batch, CH4_batch)
    ])

    # Convert to a tensor and move to GPU
    tensor_batch = torch.tensor(X_data_batch, dtype=torch.float32).to(device)

    # Use AMP for mixed precision
    with torch.cuda.amp.autocast():
        with torch.no_grad():  # Disable gradient computation for inference
            outputs = model(tensor_batch)
            _, predicted_labels = torch.max(outputs, 1)
            scores.extend(predicted_labels.cpu().tolist())

    # Calculate time taken for the batch
    batch_time = time.time() - start_time

    # Progress tracker
    current_batch = batch_idx // batch_size + 1
    percentage_complete = (current_batch / total_batches) * 100
    print(f"Processed batch {current_batch}/{total_batches} "
          f"({percentage_complete:.2f}% complete) - Time per batch: {batch_time:.2f} seconds")
# Out:
# Processed batch 1/540 (0.19% complete) - Time per batch: 12.83 seconds
# Processed batch 2/540 (0.37% complete) - Time per batch: 10.87 seconds
# Processed batch 3/540 (0.56% complete) - Time per batch: 10.87 seconds
# Processed batch 4/540 (0.74% complete) - Time per batch: 10.80 seconds
# Processed batch 5/540 (0.93% complete) - Time per batch: 10.85 seconds
# Processed batch 6/540 (1.11% complete) - Time per batch: 10.81 seconds
# Processed batch 7/540 (1.30% complete) - Time per batch: 10.93 seconds
# Processed batch 8/540 (1.48% complete) - Time per batch: 10.81 seconds
# Processed batch 9/540 (1.67% complete) - Time per batch: 11.03 seconds
# Processed batch 10/540 (1.85% complete) - Time per batch: 10.91 seconds
# Processed batch 11/540 (2.04% complete) - Time per batch: 10.82 seconds
# Processed batch 12/540 (2.22% complete) - Time per batch: 10.82 seconds
# Processed batch 13/540 (2.41% complete) - Time per batch: 10.94 seconds
# Processed batch 14/540 (2.59% complete) - Time per batch: 11.10 seconds
# Processed batch 15/540 (2.78% complete) - Time per batch: 11.06 seconds
# Processed batch 16/540 (2.96% complete) - Time per batch: 11.01 seconds
# Processed batch 17/540 (3.15% complete) - Time per batch: 10.85 seconds
# Processed batch 18/540 (3.33% complete) - Time per batch: 10.76 seconds
# Processed batch 19/540 (3.52% complete) - Time per batch: 10.93 seconds
# Processed batch 20/540 (3.70% complete) - Time per batch: 11.08 seconds
# Processed batch 21/540 (3.89% complete) - Time per batch: 10.91 seconds
# Processed batch 22/540 (4.07% complete) - Time per batch: 10.92 seconds
# Processed batch 23/540 (4.26% complete) - Time per batch: 11.01 seconds
# Processed batch 24/540 (4.44% complete) - Time per batch: 11.29 seconds
# Processed batch 25/540 (4.63% complete) - Time per batch: 10.85 seconds
# Processed batch 26/540 (4.81% complete) - Time per batch: 11.09 seconds
# Processed batch 27/540 (5.00% complete) - Time per batch: 10.98 seconds
# Processed batch 28/540 (5.19% complete) - Time per batch: 10.92 seconds
# Processed batch 29/540 (5.37% complete) - Time per batch: 10.99 seconds
# Processed batch 30/540 (5.56% complete) - Time per batch: 11.19 seconds
# Processed batch 31/540 (5.74% complete) - Time per batch: 11.06 seconds
# Processed batch 32/540 (5.93% complete) - Time per batch: 10.78 seconds
# Processed batch 33/540 (6.11% complete) - Time per batch: 11.14 seconds
# Processed batch 34/540 (6.30% complete) - Time per batch: 11.20 seconds
# Processed batch 35/540 (6.48% complete) - Time per batch: 11.05 seconds
# Processed batch 36/540 (6.67% complete) - Time per batch: 10.89 seconds
# Processed batch 37/540 (6.85% complete) - Time per batch: 10.75 seconds
# Processed batch 38/540 (7.04% complete) - Time per batch: 10.88 seconds
# Processed batch 39/540 (7.22% complete) - Time per batch: 10.89 seconds
# Processed batch 40/540 (7.41% complete) - Time per batch: 10.81 seconds
# Processed batch 41/540 (7.59% complete) - Time per batch: 10.91 seconds
# Processed batch 42/540 (7.78% complete) - Time per batch: 11.00 seconds
# Processed batch 43/540 (7.96% complete) - Time per batch: 10.85 seconds
# Processed batch 44/540 (8.15% complete) - Time per batch: 10.87 seconds
# Processed batch 45/540 (8.33% complete) - Time per batch: 10.93 seconds
# Processed batch 46/540 (8.52% complete) - Time per batch: 11.10 seconds
# Processed batch 47/540 (8.70% complete) - Time per batch: 10.86 seconds
# Processed batch 48/540 (8.89% complete) - Time per batch: 10.78 seconds
# Processed batch 49/540 (9.07% complete) - Time per batch: 10.80 seconds
# Processed batch 50/540 (9.26% complete) - Time per batch: 10.85 seconds
# Processed batch 51/540 (9.44% complete) - Time per batch: 10.98 seconds
# Processed batch 52/540 (9.63% complete) - Time per batch: 10.93 seconds
# Processed batch 53/540 (9.81% complete) - Time per batch: 10.84 seconds
# Processed batch 54/540 (10.00% complete) - Time per batch: 10.93 seconds
# Processed batch 55/540 (10.19% complete) - Time per batch: 10.83 seconds
# Processed batch 56/540 (10.37% complete) - Time per batch: 10.81 seconds
# Processed batch 57/540 (10.56% complete) - Time per batch: 11.30 seconds
# Processed batch 58/540 (10.74% complete) - Time per batch: 10.87 seconds
# Processed batch 59/540 (10.93% complete) - Time per batch: 11.04 seconds
# Processed batch 60/540 (11.11% complete) - Time per batch: 10.96 seconds
# Processed batch 61/540 (11.30% complete) - Time per batch: 10.83 seconds
# Processed batch 62/540 (11.48% complete) - Time per batch: 11.01 seconds
# Processed batch 63/540 (11.67% complete) - Time per batch: 11.14 seconds
# Processed batch 64/540 (11.85% complete) - Time per batch: 10.85 seconds
# Processed batch 65/540 (12.04% complete) - Time per batch: 10.85 seconds
# Processed batch 66/540 (12.22% complete) - Time per batch: 10.85 seconds
# Processed batch 67/540 (12.41% complete) - Time per batch: 10.84 seconds
# Processed batch 68/540 (12.59% complete) - Time per batch: 11.08 seconds
# Processed batch 69/540 (12.78% complete) - Time per batch: 10.86 seconds
# Processed batch 70/540 (12.96% complete) - Time per batch: 10.86 seconds
# Processed batch 71/540 (13.15% complete) - Time per batch: 10.79 seconds
# Processed batch 72/540 (13.33% complete) - Time per batch: 10.83 seconds
# Processed batch 73/540 (13.52% complete) - Time per batch: 10.75 seconds
# Processed batch 74/540 (13.70% complete) - Time per batch: 10.94 seconds
# Processed batch 75/540 (13.89% complete) - Time per batch: 10.88 seconds
# Processed batch 76/540 (14.07% complete) - Time per batch: 10.83 seconds
# Processed batch 77/540 (14.26% complete) - Time per batch: 10.82 seconds
# Processed batch 78/540 (14.44% complete) - Time per batch: 10.84 seconds
# Processed batch 79/540 (14.63% complete) - Time per batch: 11.20 seconds
# Processed batch 80/540 (14.81% complete) - Time per batch: 10.80 seconds
# Processed batch 81/540 (15.00% complete) - Time per batch: 10.95 seconds
# Processed batch 82/540 (15.19% complete) - Time per batch: 10.73 seconds
# Processed batch 83/540 (15.37% complete) - Time per batch: 10.83 seconds
# Processed batch 84/540 (15.56% complete) - Time per batch: 10.83 seconds
# Processed batch 85/540 (15.74% complete) - Time per batch: 11.02 seconds
# Processed batch 86/540 (15.93% complete) - Time per batch: 10.92 seconds
# Processed batch 87/540 (16.11% complete) - Time per batch: 10.91 seconds
# Processed batch 88/540 (16.30% complete) - Time per batch: 10.86 seconds
# Processed batch 89/540 (16.48% complete) - Time per batch: 10.90 seconds
# Processed batch 90/540 (16.67% complete) - Time per batch: 10.86 seconds
# Processed batch 91/540 (16.85% complete) - Time per batch: 10.74 seconds
# Processed batch 92/540 (17.04% complete) - Time per batch: 10.90 seconds
# Processed batch 93/540 (17.22% complete) - Time per batch: 10.74 seconds
# Processed batch 94/540 (17.41% complete) - Time per batch: 10.88 seconds
# Processed batch 95/540 (17.59% complete) - Time per batch: 10.77 seconds
# Processed batch 96/540 (17.78% complete) - Time per batch: 10.84 seconds
# Processed batch 97/540 (17.96% complete) - Time per batch: 10.87 seconds
# Processed batch 98/540 (18.15% complete) - Time per batch: 10.97 seconds
# Processed batch 99/540 (18.33% complete) - Time per batch: 10.95 seconds
# Processed batch 100/540 (18.52% complete) - Time per batch: 10.87 seconds
# Processed batch 101/540 (18.70% complete) - Time per batch: 11.00 seconds
# Processed batch 102/540 (18.89% complete) - Time per batch: 10.97 seconds
# Processed batch 103/540 (19.07% complete) - Time per batch: 10.84 seconds
# Processed batch 104/540 (19.26% complete) - Time per batch: 10.85 seconds
# Processed batch 105/540 (19.44% complete) - Time per batch: 10.70 seconds
# Processed batch 106/540 (19.63% complete) - Time per batch: 10.85 seconds
# Processed batch 107/540 (19.81% complete) - Time per batch: 10.84 seconds
# Processed batch 108/540 (20.00% complete) - Time per batch: 10.84 seconds
# Processed batch 109/540 (20.19% complete) - Time per batch: 11.00 seconds
# Processed batch 110/540 (20.37% complete) - Time per batch: 10.86 seconds
# Processed batch 111/540 (20.56% complete) - Time per batch: 10.85 seconds
# Processed batch 112/540 (20.74% complete) - Time per batch: 11.16 seconds
# Processed batch 113/540 (20.93% complete) - Time per batch: 10.96 seconds
# Processed batch 114/540 (21.11% complete) - Time per batch: 10.92 seconds
# Processed batch 115/540 (21.30% complete) - Time per batch: 10.90 seconds
# Processed batch 116/540 (21.48% complete) - Time per batch: 10.92 seconds
# Processed batch 117/540 (21.67% complete) - Time per batch: 10.82 seconds
# Processed batch 118/540 (21.85% complete) - Time per batch: 11.18 seconds
# Processed batch 119/540 (22.04% complete) - Time per batch: 10.85 seconds
# Processed batch 120/540 (22.22% complete) - Time per batch: 10.82 seconds
# Processed batch 121/540 (22.41% complete) - Time per batch: 10.80 seconds
# Processed batch 122/540 (22.59% complete) - Time per batch: 10.75 seconds
# Processed batch 123/540 (22.78% complete) - Time per batch: 11.14 seconds
# Processed batch 124/540 (22.96% complete) - Time per batch: 10.86 seconds
# Processed batch 125/540 (23.15% complete) - Time per batch: 10.81 seconds
# Processed batch 126/540 (23.33% complete) - Time per batch: 10.99 seconds
# Processed batch 127/540 (23.52% complete) - Time per batch: 10.82 seconds
# Processed batch 128/540 (23.70% complete) - Time per batch: 10.80 seconds
# Processed batch 129/540 (23.89% complete) - Time per batch: 10.81 seconds
# Processed batch 130/540 (24.07% complete) - Time per batch: 10.90 seconds
# Processed batch 131/540 (24.26% complete) - Time per batch: 10.96 seconds
# Processed batch 132/540 (24.44% complete) - Time per batch: 10.85 seconds
# Processed batch 133/540 (24.63% complete) - Time per batch: 10.83 seconds
# Processed batch 134/540 (24.81% complete) - Time per batch: 11.20 seconds
# Processed batch 135/540 (25.00% complete) - Time per batch: 10.83 seconds
# Processed batch 136/540 (25.19% complete) - Time per batch: 10.84 seconds
# Processed batch 137/540 (25.37% complete) - Time per batch: 10.94 seconds
# Processed batch 138/540 (25.56% complete) - Time per batch: 10.71 seconds
# Processed batch 139/540 (25.74% complete) - Time per batch: 10.80 seconds
# Processed batch 140/540 (25.93% complete) - Time per batch: 10.88 seconds
# Processed batch 141/540 (26.11% complete) - Time per batch: 11.06 seconds
# Processed batch 142/540 (26.30% complete) - Time per batch: 10.85 seconds
# Processed batch 143/540 (26.48% complete) - Time per batch: 10.97 seconds
# Processed batch 144/540 (26.67% complete) - Time per batch: 11.15 seconds
# Processed batch 145/540 (26.85% complete) - Time per batch: 11.08 seconds
# Processed batch 146/540 (27.04% complete) - Time per batch: 10.75 seconds
# Processed batch 147/540 (27.22% complete) - Time per batch: 10.85 seconds
# Processed batch 148/540 (27.41% complete) - Time per batch: 10.79 seconds
# Processed batch 149/540 (27.59% complete) - Time per batch: 10.77 seconds
# Processed batch 150/540 (27.78% complete) - Time per batch: 10.88 seconds
# Processed batch 151/540 (27.96% complete) - Time per batch: 10.85 seconds
# Processed batch 152/540 (28.15% complete) - Time per batch: 10.85 seconds
# Processed batch 153/540 (28.33% complete) - Time per batch: 10.98 seconds
# Processed batch 154/540 (28.52% complete) - Time per batch: 10.87 seconds
# Processed batch 155/540 (28.70% complete) - Time per batch: 10.90 seconds
# Processed batch 156/540 (28.89% complete) - Time per batch: 11.05 seconds
# Processed batch 157/540 (29.07% complete) - Time per batch: 10.97 seconds
# Processed batch 158/540 (29.26% complete) - Time per batch: 10.84 seconds
# Processed batch 159/540 (29.44% complete) - Time per batch: 10.94 seconds
# Processed batch 160/540 (29.63% complete) - Time per batch: 10.77 seconds
# Processed batch 161/540 (29.81% complete) - Time per batch: 10.82 seconds
# Processed batch 162/540 (30.00% complete) - Time per batch: 10.85 seconds
# Processed batch 163/540 (30.19% complete) - Time per batch: 10.85 seconds
# Processed batch 164/540 (30.37% complete) - Time per batch: 10.93 seconds
# Processed batch 165/540 (30.56% complete) - Time per batch: 10.97 seconds
# Processed batch 166/540 (30.74% complete) - Time per batch: 10.75 seconds
# Processed batch 167/540 (30.93% complete) - Time per batch: 11.18 seconds
# Processed batch 168/540 (31.11% complete) - Time per batch: 10.92 seconds
# Processed batch 169/540 (31.30% complete) - Time per batch: 10.89 seconds
# Processed batch 170/540 (31.48% complete) - Time per batch: 10.93 seconds
# Processed batch 171/540 (31.67% complete) - Time per batch: 10.88 seconds
# Processed batch 172/540 (31.85% complete) - Time per batch: 10.70 seconds
# Processed batch 173/540 (32.04% complete) - Time per batch: 11.14 seconds
# Processed batch 174/540 (32.22% complete) - Time per batch: 10.73 seconds
# Processed batch 175/540 (32.41% complete) - Time per batch: 10.84 seconds
# Processed batch 176/540 (32.59% complete) - Time per batch: 10.81 seconds
# Processed batch 177/540 (32.78% complete) - Time per batch: 10.82 seconds
# Processed batch 178/540 (32.96% complete) - Time per batch: 11.28 seconds
# Processed batch 179/540 (33.15% complete) - Time per batch: 11.04 seconds
# Processed batch 180/540 (33.33% complete) - Time per batch: 10.89 seconds
# Processed batch 181/540 (33.52% complete) - Time per batch: 11.12 seconds
# Processed batch 182/540 (33.70% complete) - Time per batch: 10.46 seconds
# Processed batch 183/540 (33.89% complete) - Time per batch: 10.35 seconds
# Processed batch 184/540 (34.07% complete) - Time per batch: 10.30 seconds
# Processed batch 185/540 (34.26% complete) - Time per batch: 10.31 seconds
# Processed batch 186/540 (34.44% complete) - Time per batch: 10.35 seconds
# Processed batch 187/540 (34.63% complete) - Time per batch: 10.91 seconds
# Processed batch 188/540 (34.81% complete) - Time per batch: 10.36 seconds
# Processed batch 189/540 (35.00% complete) - Time per batch: 10.30 seconds
# Processed batch 190/540 (35.19% complete) - Time per batch: 10.38 seconds
# Processed batch 191/540 (35.37% complete) - Time per batch: 10.40 seconds
# Processed batch 192/540 (35.56% complete) - Time per batch: 10.32 seconds
# Processed batch 193/540 (35.74% complete) - Time per batch: 10.33 seconds
# Processed batch 194/540 (35.93% complete) - Time per batch: 10.28 seconds
# Processed batch 195/540 (36.11% complete) - Time per batch: 10.22 seconds
# Processed batch 196/540 (36.30% complete) - Time per batch: 10.66 seconds
# Processed batch 197/540 (36.48% complete) - Time per batch: 10.30 seconds
# Processed batch 198/540 (36.67% complete) - Time per batch: 10.32 seconds
# Processed batch 199/540 (36.85% complete) - Time per batch: 10.39 seconds
# Processed batch 200/540 (37.04% complete) - Time per batch: 10.28 seconds
# Processed batch 201/540 (37.22% complete) - Time per batch: 10.32 seconds
# Processed batch 202/540 (37.41% complete) - Time per batch: 10.26 seconds
# Processed batch 203/540 (37.59% complete) - Time per batch: 10.26 seconds
# Processed batch 204/540 (37.78% complete) - Time per batch: 10.32 seconds
# Processed batch 205/540 (37.96% complete) - Time per batch: 10.76 seconds
# Processed batch 206/540 (38.15% complete) - Time per batch: 10.29 seconds
# Processed batch 207/540 (38.33% complete) - Time per batch: 10.32 seconds
# Processed batch 208/540 (38.52% complete) - Time per batch: 10.25 seconds
# Processed batch 209/540 (38.70% complete) - Time per batch: 10.28 seconds
# Processed batch 210/540 (38.89% complete) - Time per batch: 10.42 seconds
# Processed batch 211/540 (39.07% complete) - Time per batch: 10.35 seconds
# Processed batch 212/540 (39.26% complete) - Time per batch: 10.32 seconds
# Processed batch 213/540 (39.44% complete) - Time per batch: 10.72 seconds
# Processed batch 214/540 (39.63% complete) - Time per batch: 10.32 seconds
# Processed batch 215/540 (39.81% complete) - Time per batch: 10.33 seconds
# Processed batch 216/540 (40.00% complete) - Time per batch: 10.52 seconds
# Processed batch 217/540 (40.19% complete) - Time per batch: 10.37 seconds
# Processed batch 218/540 (40.37% complete) - Time per batch: 10.40 seconds
# Processed batch 219/540 (40.56% complete) - Time per batch: 10.29 seconds
# Processed batch 220/540 (40.74% complete) - Time per batch: 10.34 seconds
# Processed batch 221/540 (40.93% complete) - Time per batch: 10.40 seconds
# Processed batch 222/540 (41.11% complete) - Time per batch: 10.36 seconds
# Processed batch 223/540 (41.30% complete) - Time per batch: 10.42 seconds
# Processed batch 224/540 (41.48% complete) - Time per batch: 10.63 seconds
# Processed batch 225/540 (41.67% complete) - Time per batch: 10.47 seconds
# Processed batch 226/540 (41.85% complete) - Time per batch: 10.26 seconds
# Processed batch 227/540 (42.04% complete) - Time per batch: 10.39 seconds
# Processed batch 228/540 (42.22% complete) - Time per batch: 10.36 seconds
# Processed batch 229/540 (42.41% complete) - Time per batch: 10.33 seconds
# Processed batch 230/540 (42.59% complete) - Time per batch: 10.54 seconds
# Processed batch 231/540 (42.78% complete) - Time per batch: 10.48 seconds
# Processed batch 232/540 (42.96% complete) - Time per batch: 10.33 seconds
# Processed batch 233/540 (43.15% complete) - Time per batch: 10.49 seconds
# Processed batch 234/540 (43.33% complete) - Time per batch: 10.22 seconds
# Processed batch 235/540 (43.52% complete) - Time per batch: 10.36 seconds
# Processed batch 236/540 (43.70% complete) - Time per batch: 10.78 seconds
# Processed batch 237/540 (43.89% complete) - Time per batch: 10.36 seconds
# Processed batch 238/540 (44.07% complete) - Time per batch: 10.39 seconds
# Processed batch 239/540 (44.26% complete) - Time per batch: 10.66 seconds
# Processed batch 240/540 (44.44% complete) - Time per batch: 10.32 seconds
# Processed batch 241/540 (44.63% complete) - Time per batch: 10.29 seconds
# Processed batch 242/540 (44.81% complete) - Time per batch: 10.41 seconds
# Processed batch 243/540 (45.00% complete) - Time per batch: 10.40 seconds
# Processed batch 244/540 (45.19% complete) - Time per batch: 10.37 seconds
# Processed batch 245/540 (45.37% complete) - Time per batch: 10.33 seconds
# Processed batch 246/540 (45.56% complete) - Time per batch: 10.29 seconds
# Processed batch 247/540 (45.74% complete) - Time per batch: 10.26 seconds
# Processed batch 248/540 (45.93% complete) - Time per batch: 10.78 seconds
# Processed batch 249/540 (46.11% complete) - Time per batch: 10.33 seconds
# Processed batch 250/540 (46.30% complete) - Time per batch: 10.30 seconds
# Processed batch 251/540 (46.48% complete) - Time per batch: 10.40 seconds
# Processed batch 252/540 (46.67% complete) - Time per batch: 10.33 seconds
# Processed batch 253/540 (46.85% complete) - Time per batch: 10.26 seconds
# Processed batch 254/540 (47.04% complete) - Time per batch: 10.69 seconds
# Processed batch 255/540 (47.22% complete) - Time per batch: 10.29 seconds
# Processed batch 256/540 (47.41% complete) - Time per batch: 10.34 seconds
# Processed batch 257/540 (47.59% complete) - Time per batch: 10.87 seconds
# Processed batch 258/540 (47.78% complete) - Time per batch: 10.32 seconds
# Processed batch 259/540 (47.96% complete) - Time per batch: 10.44 seconds
# Processed batch 260/540 (48.15% complete) - Time per batch: 10.32 seconds
# Processed batch 261/540 (48.33% complete) - Time per batch: 10.37 seconds
# Processed batch 262/540 (48.52% complete) - Time per batch: 10.43 seconds
# Processed batch 263/540 (48.70% complete) - Time per batch: 10.32 seconds
# Processed batch 264/540 (48.89% complete) - Time per batch: 10.27 seconds
# Processed batch 265/540 (49.07% complete) - Time per batch: 10.30 seconds
# Processed batch 266/540 (49.26% complete) - Time per batch: 10.29 seconds
# Processed batch 267/540 (49.44% complete) - Time per batch: 10.25 seconds
# Processed batch 268/540 (49.63% complete) - Time per batch: 10.40 seconds
# Processed batch 269/540 (49.81% complete) - Time per batch: 10.28 seconds
# Processed batch 270/540 (50.00% complete) - Time per batch: 10.29 seconds
# Processed batch 271/540 (50.19% complete) - Time per batch: 10.82 seconds
# Processed batch 272/540 (50.37% complete) - Time per batch: 10.30 seconds
# Processed batch 273/540 (50.56% complete) - Time per batch: 10.36 seconds
# Processed batch 274/540 (50.74% complete) - Time per batch: 10.38 seconds
# Processed batch 275/540 (50.93% complete) - Time per batch: 10.30 seconds
# Processed batch 276/540 (51.11% complete) - Time per batch: 10.29 seconds
# Processed batch 277/540 (51.30% complete) - Time per batch: 10.20 seconds
# Processed batch 278/540 (51.48% complete) - Time per batch: 10.29 seconds
# Processed batch 279/540 (51.67% complete) - Time per batch: 10.35 seconds
# Processed batch 280/540 (51.85% complete) - Time per batch: 10.45 seconds
# Processed batch 281/540 (52.04% complete) - Time per batch: 10.22 seconds
# Processed batch 282/540 (52.22% complete) - Time per batch: 10.85 seconds
# Processed batch 283/540 (52.41% complete) - Time per batch: 10.40 seconds
# Processed batch 284/540 (52.59% complete) - Time per batch: 10.37 seconds
# Processed batch 285/540 (52.78% complete) - Time per batch: 10.68 seconds
# Processed batch 286/540 (52.96% complete) - Time per batch: 10.58 seconds
# Processed batch 287/540 (53.15% complete) - Time per batch: 11.15 seconds
# Processed batch 288/540 (53.33% complete) - Time per batch: 11.08 seconds
# Processed batch 289/540 (53.52% complete) - Time per batch: 11.38 seconds
# Processed batch 290/540 (53.70% complete) - Time per batch: 11.19 seconds
# Processed batch 291/540 (53.89% complete) - Time per batch: 10.84 seconds
# Processed batch 292/540 (54.07% complete) - Time per batch: 13.10 seconds
# Processed batch 293/540 (54.26% complete) - Time per batch: 13.59 seconds
# Processed batch 294/540 (54.44% complete) - Time per batch: 14.06 seconds
# Processed batch 295/540 (54.63% complete) - Time per batch: 16.10 seconds
# Processed batch 296/540 (54.81% complete) - Time per batch: 57.07 seconds
# Processed batch 297/540 (55.00% complete) - Time per batch: 80.27 seconds
# Processed batch 298/540 (55.19% complete) - Time per batch: 70.96 seconds
# Processed batch 299/540 (55.37% complete) - Time per batch: 55.32 seconds
# Processed batch 300/540 (55.56% complete) - Time per batch: 14.08 seconds
# Processed batch 301/540 (55.74% complete) - Time per batch: 13.24 seconds
# Processed batch 302/540 (55.93% complete) - Time per batch: 12.79 seconds
# Processed batch 303/540 (56.11% complete) - Time per batch: 13.83 seconds
# Processed batch 304/540 (56.30% complete) - Time per batch: 13.81 seconds
# Processed batch 305/540 (56.48% complete) - Time per batch: 13.84 seconds
# Processed batch 306/540 (56.67% complete) - Time per batch: 14.34 seconds
# Processed batch 307/540 (56.85% complete) - Time per batch: 13.42 seconds
# Processed batch 308/540 (57.04% complete) - Time per batch: 13.15 seconds
# Processed batch 309/540 (57.22% complete) - Time per batch: 12.81 seconds
# Processed batch 310/540 (57.41% complete) - Time per batch: 11.94 seconds
# Processed batch 311/540 (57.59% complete) - Time per batch: 10.77 seconds
# Processed batch 312/540 (57.78% complete) - Time per batch: 10.74 seconds
# Processed batch 313/540 (57.96% complete) - Time per batch: 10.70 seconds
# Processed batch 314/540 (58.15% complete) - Time per batch: 10.63 seconds
# Processed batch 315/540 (58.33% complete) - Time per batch: 10.51 seconds
# Processed batch 316/540 (58.52% complete) - Time per batch: 10.43 seconds
# Processed batch 317/540 (58.70% complete) - Time per batch: 10.60 seconds
# Processed batch 318/540 (58.89% complete) - Time per batch: 10.51 seconds
# Processed batch 319/540 (59.07% complete) - Time per batch: 10.81 seconds
# Processed batch 320/540 (59.26% complete) - Time per batch: 10.56 seconds
# Processed batch 321/540 (59.44% complete) - Time per batch: 10.58 seconds
# Processed batch 322/540 (59.63% complete) - Time per batch: 10.33 seconds
# Processed batch 323/540 (59.81% complete) - Time per batch: 10.59 seconds
# Processed batch 324/540 (60.00% complete) - Time per batch: 12.92 seconds
# Processed batch 325/540 (60.19% complete) - Time per batch: 12.58 seconds
# Processed batch 326/540 (60.37% complete) - Time per batch: 11.03 seconds
# Processed batch 327/540 (60.56% complete) - Time per batch: 10.42 seconds
# Processed batch 328/540 (60.74% complete) - Time per batch: 10.55 seconds
# Processed batch 329/540 (60.93% complete) - Time per batch: 25.79 seconds
# Processed batch 330/540 (61.11% complete) - Time per batch: 12.67 seconds
# Processed batch 331/540 (61.30% complete) - Time per batch: 11.54 seconds
# Processed batch 332/540 (61.48% complete) - Time per batch: 10.75 seconds
# Processed batch 333/540 (61.67% complete) - Time per batch: 10.49 seconds
# Processed batch 334/540 (61.85% complete) - Time per batch: 10.51 seconds
# Processed batch 335/540 (62.04% complete) - Time per batch: 10.31 seconds
# Processed batch 336/540 (62.22% complete) - Time per batch: 10.68 seconds
# Processed batch 337/540 (62.41% complete) - Time per batch: 10.74 seconds
# Processed batch 338/540 (62.59% complete) - Time per batch: 16.21 seconds
# Processed batch 339/540 (62.78% complete) - Time per batch: 10.66 seconds
# Processed batch 340/540 (62.96% complete) - Time per batch: 10.84 seconds
# Processed batch 341/540 (63.15% complete) - Time per batch: 10.86 seconds
# Processed batch 342/540 (63.33% complete) - Time per batch: 10.44 seconds
# Processed batch 343/540 (63.52% complete) - Time per batch: 15.24 seconds
# Processed batch 344/540 (63.70% complete) - Time per batch: 10.71 seconds
# Processed batch 345/540 (63.89% complete) - Time per batch: 10.73 seconds
# Processed batch 346/540 (64.07% complete) - Time per batch: 10.78 seconds
# Processed batch 347/540 (64.26% complete) - Time per batch: 10.60 seconds
# Processed batch 348/540 (64.44% complete) - Time per batch: 10.90 seconds
# Processed batch 349/540 (64.63% complete) - Time per batch: 11.05 seconds
# Processed batch 350/540 (64.81% complete) - Time per batch: 10.49 seconds
# Processed batch 351/540 (65.00% complete) - Time per batch: 10.42 seconds
# Processed batch 352/540 (65.19% complete) - Time per batch: 10.58 seconds
# Processed batch 353/540 (65.37% complete) - Time per batch: 10.50 seconds
# Processed batch 354/540 (65.56% complete) - Time per batch: 10.46 seconds
# Processed batch 355/540 (65.74% complete) - Time per batch: 10.70 seconds
# Processed batch 356/540 (65.93% complete) - Time per batch: 10.68 seconds
# Processed batch 357/540 (66.11% complete) - Time per batch: 10.47 seconds
# Processed batch 358/540 (66.30% complete) - Time per batch: 10.58 seconds
# Processed batch 359/540 (66.48% complete) - Time per batch: 10.61 seconds
# Processed batch 360/540 (66.67% complete) - Time per batch: 10.68 seconds
# Processed batch 361/540 (66.85% complete) - Time per batch: 10.53 seconds
# Processed batch 362/540 (67.04% complete) - Time per batch: 10.55 seconds
# Processed batch 363/540 (67.22% complete) - Time per batch: 10.81 seconds
# Processed batch 364/540 (67.41% complete) - Time per batch: 10.81 seconds
# Processed batch 365/540 (67.59% complete) - Time per batch: 10.93 seconds
# Processed batch 366/540 (67.78% complete) - Time per batch: 10.78 seconds
# Processed batch 367/540 (67.96% complete) - Time per batch: 10.77 seconds
# Processed batch 368/540 (68.15% complete) - Time per batch: 10.90 seconds
# Processed batch 369/540 (68.33% complete) - Time per batch: 10.85 seconds
# Processed batch 370/540 (68.52% complete) - Time per batch: 10.97 seconds
# Processed batch 371/540 (68.70% complete) - Time per batch: 11.32 seconds
# Processed batch 372/540 (68.89% complete) - Time per batch: 10.88 seconds
# Processed batch 373/540 (69.07% complete) - Time per batch: 10.88 seconds
# Processed batch 374/540 (69.26% complete) - Time per batch: 10.90 seconds
# Processed batch 375/540 (69.44% complete) - Time per batch: 10.97 seconds
# Processed batch 376/540 (69.63% complete) - Time per batch: 11.14 seconds
# Processed batch 377/540 (69.81% complete) - Time per batch: 11.64 seconds
# Processed batch 378/540 (70.00% complete) - Time per batch: 10.88 seconds
# Processed batch 379/540 (70.19% complete) - Time per batch: 10.85 seconds
# Processed batch 380/540 (70.37% complete) - Time per batch: 11.02 seconds
# Processed batch 381/540 (70.56% complete) - Time per batch: 10.88 seconds
# Processed batch 382/540 (70.74% complete) - Time per batch: 11.03 seconds
# Processed batch 383/540 (70.93% complete) - Time per batch: 10.91 seconds
# Processed batch 384/540 (71.11% complete) - Time per batch: 10.98 seconds
# Processed batch 385/540 (71.30% complete) - Time per batch: 10.83 seconds
# Processed batch 386/540 (71.48% complete) - Time per batch: 10.88 seconds
# Processed batch 387/540 (71.67% complete) - Time per batch: 11.12 seconds
# Processed batch 388/540 (71.85% complete) - Time per batch: 11.25 seconds
# Processed batch 389/540 (72.04% complete) - Time per batch: 10.61 seconds
# Processed batch 390/540 (72.22% complete) - Time per batch: 10.83 seconds
# Processed batch 391/540 (72.41% complete) - Time per batch: 10.58 seconds
# Processed batch 392/540 (72.59% complete) - Time per batch: 10.55 seconds
# Processed batch 393/540 (72.78% complete) - Time per batch: 10.63 seconds
# Processed batch 394/540 (72.96% complete) - Time per batch: 10.51 seconds
# Processed batch 395/540 (73.15% complete) - Time per batch: 10.40 seconds
# Processed batch 396/540 (73.33% complete) - Time per batch: 10.33 seconds
# Processed batch 397/540 (73.52% complete) - Time per batch: 10.58 seconds
# Processed batch 398/540 (73.70% complete) - Time per batch: 10.65 seconds
# Processed batch 399/540 (73.89% complete) - Time per batch: 10.41 seconds
# Processed batch 400/540 (74.07% complete) - Time per batch: 10.46 seconds
# Processed batch 401/540 (74.26% complete) - Time per batch: 10.71 seconds
# Processed batch 402/540 (74.44% complete) - Time per batch: 10.87 seconds
# Processed batch 403/540 (74.63% complete) - Time per batch: 11.05 seconds
# Processed batch 404/540 (74.81% complete) - Time per batch: 10.77 seconds
# Processed batch 405/540 (75.00% complete) - Time per batch: 12.21 seconds
# Processed batch 406/540 (75.19% complete) - Time per batch: 12.52 seconds
# Processed batch 407/540 (75.37% complete) - Time per batch: 10.89 seconds
# Processed batch 408/540 (75.56% complete) - Time per batch: 11.34 seconds
# Processed batch 409/540 (75.74% complete) - Time per batch: 11.14 seconds
# Processed batch 410/540 (75.93% complete) - Time per batch: 10.73 seconds
# Processed batch 411/540 (76.11% complete) - Time per batch: 10.95 seconds
# Processed batch 412/540 (76.30% complete) - Time per batch: 11.30 seconds
# Processed batch 413/540 (76.48% complete) - Time per batch: 10.78 seconds
# Processed batch 414/540 (76.67% complete) - Time per batch: 10.81 seconds
# Processed batch 415/540 (76.85% complete) - Time per batch: 10.83 seconds
# Processed batch 416/540 (77.04% complete) - Time per batch: 10.77 seconds
# Processed batch 417/540 (77.22% complete) - Time per batch: 10.36 seconds
# Processed batch 418/540 (77.41% complete) - Time per batch: 10.32 seconds
# Processed batch 419/540 (77.59% complete) - Time per batch: 10.48 seconds
# Processed batch 420/540 (77.78% complete) - Time per batch: 10.37 seconds
# Processed batch 421/540 (77.96% complete) - Time per batch: 10.46 seconds
# Processed batch 422/540 (78.15% complete) - Time per batch: 10.66 seconds
# Processed batch 423/540 (78.33% complete) - Time per batch: 10.46 seconds
# Processed batch 424/540 (78.52% complete) - Time per batch: 10.43 seconds
# Processed batch 425/540 (78.70% complete) - Time per batch: 10.39 seconds
# Processed batch 426/540 (78.89% complete) - Time per batch: 10.53 seconds
# Processed batch 427/540 (79.07% complete) - Time per batch: 10.43 seconds
# Processed batch 428/540 (79.26% complete) - Time per batch: 10.37 seconds
# Processed batch 429/540 (79.44% complete) - Time per batch: 10.35 seconds
# Processed batch 430/540 (79.63% complete) - Time per batch: 10.36 seconds
# Processed batch 431/540 (79.81% complete) - Time per batch: 10.45 seconds
# Processed batch 432/540 (80.00% complete) - Time per batch: 10.49 seconds
# Processed batch 433/540 (80.19% complete) - Time per batch: 10.84 seconds
# Processed batch 434/540 (80.37% complete) - Time per batch: 10.40 seconds
# Processed batch 435/540 (80.56% complete) - Time per batch: 10.35 seconds
# Processed batch 436/540 (80.74% complete) - Time per batch: 10.39 seconds
# Processed batch 437/540 (80.93% complete) - Time per batch: 10.42 seconds
# Processed batch 438/540 (81.11% complete) - Time per batch: 10.64 seconds
# Processed batch 439/540 (81.30% complete) - Time per batch: 10.63 seconds
# Processed batch 440/540 (81.48% complete) - Time per batch: 10.45 seconds
# Processed batch 441/540 (81.67% complete) - Time per batch: 10.39 seconds
# Processed batch 442/540 (81.85% complete) - Time per batch: 10.38 seconds
# Processed batch 443/540 (82.04% complete) - Time per batch: 10.32 seconds
# Processed batch 444/540 (82.22% complete) - Time per batch: 10.35 seconds
# Processed batch 445/540 (82.41% complete) - Time per batch: 10.36 seconds
# Processed batch 446/540 (82.59% complete) - Time per batch: 10.34 seconds
# Processed batch 447/540 (82.78% complete) - Time per batch: 10.33 seconds
# Processed batch 448/540 (82.96% complete) - Time per batch: 10.34 seconds
# Processed batch 449/540 (83.15% complete) - Time per batch: 10.36 seconds
# Processed batch 450/540 (83.33% complete) - Time per batch: 10.80 seconds
# Processed batch 451/540 (83.52% complete) - Time per batch: 10.39 seconds
# Processed batch 452/540 (83.70% complete) - Time per batch: 10.27 seconds
# Processed batch 453/540 (83.89% complete) - Time per batch: 10.38 seconds
# Processed batch 454/540 (84.07% complete) - Time per batch: 10.46 seconds
# Processed batch 455/540 (84.26% complete) - Time per batch: 10.53 seconds
# Processed batch 456/540 (84.44% complete) - Time per batch: 10.33 seconds
# Processed batch 457/540 (84.63% complete) - Time per batch: 10.72 seconds
# Processed batch 458/540 (84.81% complete) - Time per batch: 10.46 seconds
# Processed batch 459/540 (85.00% complete) - Time per batch: 10.34 seconds
# Processed batch 460/540 (85.19% complete) - Time per batch: 10.89 seconds
# Processed batch 461/540 (85.37% complete) - Time per batch: 10.94 seconds
# Processed batch 462/540 (85.56% complete) - Time per batch: 11.15 seconds
# Processed batch 463/540 (85.74% complete) - Time per batch: 10.97 seconds
# Processed batch 464/540 (85.93% complete) - Time per batch: 10.83 seconds
# Processed batch 465/540 (86.11% complete) - Time per batch: 10.87 seconds
# Processed batch 466/540 (86.30% complete) - Time per batch: 10.91 seconds
# Processed batch 467/540 (86.48% complete) - Time per batch: 11.09 seconds
# Processed batch 468/540 (86.67% complete) - Time per batch: 11.01 seconds
# Processed batch 469/540 (86.85% complete) - Time per batch: 10.87 seconds
# Processed batch 470/540 (87.04% complete) - Time per batch: 10.90 seconds
# Processed batch 471/540 (87.22% complete) - Time per batch: 10.89 seconds
# Processed batch 472/540 (87.41% complete) - Time per batch: 11.00 seconds
# Processed batch 473/540 (87.59% complete) - Time per batch: 11.11 seconds
# Processed batch 474/540 (87.78% complete) - Time per batch: 11.07 seconds
# Processed batch 475/540 (87.96% complete) - Time per batch: 10.82 seconds
# Processed batch 476/540 (88.15% complete) - Time per batch: 10.97 seconds
# Processed batch 477/540 (88.33% complete) - Time per batch: 10.72 seconds
# Processed batch 478/540 (88.52% complete) - Time per batch: 10.83 seconds
# Processed batch 479/540 (88.70% complete) - Time per batch: 11.10 seconds
# Processed batch 480/540 (88.89% complete) - Time per batch: 10.75 seconds
# Processed batch 481/540 (89.07% complete) - Time per batch: 10.87 seconds
# Processed batch 482/540 (89.26% complete) - Time per batch: 11.45 seconds
# Processed batch 483/540 (89.44% complete) - Time per batch: 10.93 seconds
# Processed batch 484/540 (89.63% complete) - Time per batch: 11.02 seconds
# Processed batch 485/540 (89.81% complete) - Time per batch: 10.92 seconds
# Processed batch 486/540 (90.00% complete) - Time per batch: 10.84 seconds
# Processed batch 487/540 (90.19% complete) - Time per batch: 10.92 seconds
# Processed batch 488/540 (90.37% complete) - Time per batch: 10.90 seconds
# Processed batch 489/540 (90.56% complete) - Time per batch: 10.99 seconds
# Processed batch 490/540 (90.74% complete) - Time per batch: 10.85 seconds
# Processed batch 491/540 (90.93% complete) - Time per batch: 10.79 seconds
# Processed batch 492/540 (91.11% complete) - Time per batch: 10.82 seconds
# Processed batch 493/540 (91.30% complete) - Time per batch: 10.80 seconds
# Processed batch 494/540 (91.48% complete) - Time per batch: 10.83 seconds
# Processed batch 495/540 (91.67% complete) - Time per batch: 10.76 seconds
# Processed batch 496/540 (91.85% complete) - Time per batch: 11.09 seconds

# %%
np.save('scores.npy', scores)
