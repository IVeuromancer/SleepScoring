# %%
#import packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from random import randrange, sample
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
import mne
from pickle import dump, load
import torch
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset, random_split
import torch.nn as nn
import torch.nn.functional as F

# %%
EEG_files = ['../../code/LabCode/Fiber_photometry/mouse_653/mouse_653_230316.edf',
            '../../code/LabCode/Fiber_photometry/mouse_807/mouse_807_230511.edf', 
            '../../code/LabCode/Fiber_photometry/mouse_838/mouse_838_230525.edf', 
            '../../code/LabCode/Fiber_photometry/mouse_994/mouse_994_230713.edf', 
            '../../code/LabCode/Fiber_photometry/mouse_998/mouse_998_230727.edf', 
            '../../code/LabCode/Fiber_photometry/mouse_1002/mouse_1002_230725.edf']
scores_files = ['../../code/LabCode/Fiber_photometry/mouse_653/mouse_653_230316_scores.tsv',
                '../../code/LabCode/Fiber_photometry/mouse_807/mouse_807_230511_scores.tsv',
                '../../code/LabCode/Fiber_photometry/mouse_838/mouse_838_230525_scores.tsv', 
                '../../code/LabCode/Fiber_photometry/mouse_998/mouse_998_230727_scores.tsv', 
                '../../code/LabCode/Fiber_photometry/mouse_994/mouse_994_230713_scores.tsv', 
                '../../code/LabCode/Fiber_photometry/mouse_1002/mouse_1002_230725_scores.tsv']
epoch_limits = [8640,
                8640,
                8640,
                8640,
                8640,
                8640]

# %%
all_data = []
scores_converted = []
for EEG,scores_l,limits in zip(EEG_files,scores_files,epoch_limits):
    raw = mne.io.read_raw_edf(EEG, preload=True, verbose = False)
    sf = raw.info['sfreq']
    print('Data shape (channels, times) =', raw._data.shape)
    scores = pd.read_csv(scores_l, skiprows=10, delim_whitespace=True)
    scores_array = scores['Time.2']
    for i in range(limits): 
        all_data.append([raw._data[0][i*1280:(i+1)*1280], raw._data[1][i*1280:(i+1)*1280], raw._data[2][i*1280:(i+1)*1280]])
    # in sirenia sleep, 255 unscored, 1 wake, 2 NREM, 3 REM, 4 "parameters"
    # in Yasa -2 = Unscored, -1 = Artefact / Movement, 0 = Wake, 1 = N1 sleep, 2 = N2 sleep, 3 = N3 sleep, 4 = REM sleep
    # for sleep scoring code -2 = Unscored, -1 = Artefact / Movement, 0 = Wake, 1 = N1 sleep, 1 = N2 sleep, 1 = N3 sleep, 2 = REM sleep
        if scores_array[i]==1: # wake
            scores_converted.append(0)
        elif scores_array[i]==2: # NREM
            scores_converted.append(1)
        elif scores_array[i]==3: # REM
            scores_converted.append(2)
        elif scores_array[i]==255: # unscored
            scores_converted.append(-2)      
y = np.array(scores_converted).reshape(sum(epoch_limits),1)
data = np.array(all_data)
# Out:
# Data shape (channels, times) = (3, 11060096)
# Data shape (channels, times) = (3, 11060224)
# Data shape (channels, times) = (3, 11060224)
# Data shape (channels, times) = (4, 11060224)
# Data shape (channels, times) = (4, 11060224)
# Data shape (channels, times) = (4, 11060224)

# %%
scalers = []
normalized_data = []

for sample in range(data.shape[0]):
    sample_data = []
    for channel in range(data.shape[1]):
        scaler = StandardScaler().fit(data[sample, channel, :].reshape((-1,1)))
        scalers.append(scaler)
        normalized_segment = scaler.transform(data[sample, channel, :].reshape((-1,1)))
        sample_data.append(normalized_segment)
    normalized_data.append(np.stack(sample_data, axis=0))

normalized_data = np.array(normalized_data)
X = normalized_data.reshape((51840,3,1280))

# %%
num_mouse = len(EEG_files)
# Convert your data to tensors
X_tensor = torch.tensor(X, dtype=torch.float32)
y_tensor = torch.tensor(y, dtype=torch.long).squeeze()

# Create a list to hold datasets for each mouse
datasets = []

# Calculate the number of epochs per mouse
epochs_per_mouse = X.shape[0] // num_mouse # 8640

# Split data by mouse
for i in range(num_mouse):
    start_idx = i * epochs_per_mouse
    end_idx = start_idx + epochs_per_mouse
    mouse_dataset = TensorDataset(X_tensor[start_idx:end_idx], y_tensor[start_idx:end_idx])
    datasets.append(mouse_dataset)

# %%
# Split each mouse's data into training, validation, and test sets
train_datasets = []
val_datasets = []
test_datasets = []

for mouse_dataset in datasets:
    # Define the sizes for training, validation, and test sets (e.g., 70%, 15%, 15%)
    train_size = int(0.7 * len(mouse_dataset))
    val_size = int(0.15 * len(mouse_dataset))
    test_size = len(mouse_dataset) - train_size - val_size
    
    # Split the dataset
    train_data, val_data, test_data = random_split(mouse_dataset, [train_size, val_size, test_size])
    
    # Append to the lists
    train_datasets.append(train_data)
    val_datasets.append(val_data)
    test_datasets.append(test_data)

# Concatenate datasets from all mice to create the final training, validation, and test sets
train_dataset = torch.utils.data.ConcatDataset(train_datasets)
val_dataset = torch.utils.data.ConcatDataset(val_datasets)
test_dataset = torch.utils.data.ConcatDataset(test_datasets)

# %%
# Create data loaders
batch_size = 64
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %%
# Check for GPU availability
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

class SleepScoringModel(nn.Module):
    def __init__(self, dropout_rate=0.5, weight_decay=1e-4):
        super(SleepScoringModel, self).__init__()
        
        self.conv1 = nn.Conv1d(3, 32, kernel_size=3, stride=1, padding=1)
        self.conv2 = nn.Conv1d(32, 64, kernel_size=3, stride=1, padding=1)
        
        # Add dropout layers
        self.dropout1 = nn.Dropout(dropout_rate)
        self.dropout2 = nn.Dropout(dropout_rate)
        
        self.fc1 = nn.Linear(64 * 1280, 128)
        self.fc2 = nn.Linear(128, 3)
        
        # Add weight decay to the optimizer (e.g., Adam)
        self.weight_decay = weight_decay

    def forward(self, x):
        x = self.conv1(x)
        x = F.relu(x)
        x = self.dropout1(x)  # Apply dropout
        x = self.conv2(x)
        x = F.relu(x)
        x = self.dropout2(x)  # Apply dropout
        x = x.view(x.size(0), -1)
        x = self.fc1(x)
        x = F.relu(x)
        x = self.fc2(x)
        return x

# Create an instance of the model
model = SleepScoringModel().to(device)

# %%
# Step 2: Define the Loss Function and Optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001, weight_decay=model.weight_decay)

# %%
# Initialize variables for early stopping
best_val_loss = float('inf')  # Initialize the best validation loss to infinity
patience = 5  # Number of epochs without improvement
no_improve_epochs = 0  # Initialize the count of epochs without improvement

# Initialize empty lists to store training and validation loss and accuracy values
train_losses = []
train_accuracies = []
val_losses = []
val_accuracies = []

# Training Loop
num_epochs = 30

for epoch in range(num_epochs):
    model.train()  # Set the model to training mode
    correct = 0
    total = 0
    running_loss = 0.0
    
    for batch_X, batch_y in train_loader:
        batch_X, batch_y = batch_X.to(device), batch_y.to(device)
        optimizer.zero_grad()
        outputs = model(batch_X)
        loss = criterion(outputs, batch_y.squeeze())
        loss.backward()
        optimizer.step()
        
        # Compute accuracy for the batch
        _, predicted = torch.max(outputs.data, 1)
        total += batch_y.size(0)
        correct += (predicted == batch_y.squeeze()).sum().item()
        
        running_loss += loss.item() * batch_X.size(0)
    
    epoch_loss = running_loss / len(train_loader.dataset)
    epoch_accuracy = correct / total
    
    train_losses.append(epoch_loss)
    train_accuracies.append(epoch_accuracy)
    
    print(f"Epoch [{epoch+1}/{num_epochs}], Training Loss: {epoch_loss:.4f}, Training Accuracy: {epoch_accuracy:.4f}")

    # Validation Evaluation
    model.eval()  # Set the model to evaluation mode
    correct_val = 0
    total_val = 0
    running_loss_val = 0.0
    all_pred_labels = []
    all_true_labels = []
    
    with torch.no_grad():  # Disable gradient computation for validation
        for batch_X_val, batch_y_val in val_loader:
            batch_X_val, batch_y_val = batch_X_val.to(device), batch_y_val.to(device)
            outputs_val = model(batch_X_val)
            loss_val = criterion(outputs_val, batch_y_val.squeeze())
            
            # Compute accuracy for the validation batch
            _, predicted_val = torch.max(outputs_val.data, 1)
            total_val += batch_y_val.size(0)
            correct_val += (predicted_val == batch_y_val.squeeze()).sum().item()
            
            running_loss_val += loss_val.item() * batch_X_val.size(0)
            all_pred_labels.extend(predicted_val.cpu().numpy())
            all_true_labels.extend(batch_y_val.cpu().numpy())
            
    epoch_loss_val = running_loss_val / len(val_loader.dataset)
    epoch_accuracy_val = correct_val / total_val
    
    val_losses.append(epoch_loss_val)
    val_accuracies.append(epoch_accuracy_val)
    
    # Compute the confusion matrix
    conf_matrix = confusion_matrix(all_true_labels, all_pred_labels)

    # Calculate class-wise accuracy
    class_accuracy = conf_matrix.diagonal() / conf_matrix.sum(axis=1)
    
    print(f"Validation Loss: {epoch_loss_val:.4f}, Validation Accuracy: {epoch_accuracy_val:.4f}")
    for i, accuracy in enumerate(class_accuracy):
        print(f"Class {i}: Accuracy = {accuracy:.4f}")


#     # Check for early stopping based on validation loss
#     if epoch_loss_val < best_val_loss:
#         best_val_loss = epoch_loss_val  # Update the best validation loss
#         no_improve_epochs = 0  # Reset the count of epochs without improvement
#     else:
#         no_improve_epochs += 1  # Increment the count of epochs without improvement

#     # If no improvement for 'patience' epochs, stop training
#     if no_improve_epochs >= patience:
#         print(f"Early stopping after {epoch+1} epochs without improvement.")
#         break
# Out:
# Epoch [1/30], Training Loss: 0.8297, Training Accuracy: 0.6392
# Validation Loss: 0.7960, Validation Accuracy: 0.6721
# Class 0: Accuracy = 0.5550
# Class 1: Accuracy = 0.9176
# Class 2: Accuracy = 0.0000
# Epoch [2/30], Training Loss: 0.6345, Training Accuracy: 0.7291
# Validation Loss: 0.6827, Validation Accuracy: 0.7024
# Class 0: Accuracy = 0.5491
# Class 1: Accuracy = 0.9075
# Class 2: Accuracy = 0.6029
# Epoch [3/30], Training Loss: 0.5469, Training Accuracy: 0.7595
# Validation Loss: 0.6137, Validation Accuracy: 0.7245
# Class 0: Accuracy = 0.6135
# Class 1: Accuracy = 0.8927
# Class 2: Accuracy = 0.5206
# Epoch [4/30], Training Loss: 0.4996, Training Accuracy: 0.7781
# Validation Loss: 0.5688, Validation Accuracy: 0.7549
# Class 0: Accuracy = 0.7832
# Class 1: Accuracy = 0.7594
# Class 2: Accuracy = 0.4897
# Epoch [5/30], Training Loss: 0.4586, Training Accuracy: 0.7943
# Validation Loss: 0.5328, Validation Accuracy: 0.7697
# Class 0: Accuracy = 0.7941
# Class 1: Accuracy = 0.7637
# Class 2: Accuracy = 0.6070
# Epoch [6/30], Training Loss: 0.4227, Training Accuracy: 0.8100
# Validation Loss: 0.5181, Validation Accuracy: 0.7837
# Class 0: Accuracy = 0.8642
# Class 1: Accuracy = 0.7108
# Class 2: Accuracy = 0.6029
# Epoch [7/30], Training Loss: 0.4007, Training Accuracy: 0.8219
# Validation Loss: 0.5592, Validation Accuracy: 0.7559
# Class 0: Accuracy = 0.7782
# Class 1: Accuracy = 0.7714
# Class 2: Accuracy = 0.4671
# Epoch [8/30], Training Loss: 0.3661, Training Accuracy: 0.8370
# Validation Loss: 0.5654, Validation Accuracy: 0.7659
# Class 0: Accuracy = 0.8494
# Class 1: Accuracy = 0.7160
# Class 2: Accuracy = 0.4074
# Epoch [9/30], Training Loss: 0.3382, Training Accuracy: 0.8518
# Validation Loss: 0.5421, Validation Accuracy: 0.7791
# Class 0: Accuracy = 0.8147
# Class 1: Accuracy = 0.7637
# Class 2: Accuracy = 0.5864
# Epoch [10/30], Training Loss: 0.3170, Training Accuracy: 0.8628
# Validation Loss: 0.5755, Validation Accuracy: 0.7769
# Class 0: Accuracy = 0.8060
# Class 1: Accuracy = 0.7686
# Class 2: Accuracy = 0.5905
# Epoch [11/30], Training Loss: 0.2980, Training Accuracy: 0.8711
# Validation Loss: 0.5667, Validation Accuracy: 0.7661
# Class 0: Accuracy = 0.7810
# Class 1: Accuracy = 0.7747
# Class 2: Accuracy = 0.5844
# Epoch [12/30], Training Loss: 0.2782, Training Accuracy: 0.8835
# Validation Loss: 0.5989, Validation Accuracy: 0.7656
# Class 0: Accuracy = 0.7510
# Class 1: Accuracy = 0.8153
# Class 2: Accuracy = 0.5535
# Epoch [13/30], Training Loss: 0.2582, Training Accuracy: 0.8920
# Validation Loss: 0.6189, Validation Accuracy: 0.7666
# Class 0: Accuracy = 0.8712
# Class 1: Accuracy = 0.6656
# Class 2: Accuracy = 0.5741
# Epoch [14/30], Training Loss: 0.2421, Training Accuracy: 0.8992
# Validation Loss: 0.6230, Validation Accuracy: 0.7720
# Class 0: Accuracy = 0.8075
# Class 1: Accuracy = 0.7541
# Class 2: Accuracy = 0.5967
# Epoch [15/30], Training Loss: 0.2282, Training Accuracy: 0.9060
# Validation Loss: 0.6202, Validation Accuracy: 0.7743
# Class 0: Accuracy = 0.8342
# Class 1: Accuracy = 0.7283
# Class 2: Accuracy = 0.5844
# Epoch [16/30], Training Loss: 0.2149, Training Accuracy: 0.9134
# Validation Loss: 0.6574, Validation Accuracy: 0.7680
# Class 0: Accuracy = 0.8114
# Class 1: Accuracy = 0.7520
# Class 2: Accuracy = 0.5144
# Epoch [17/30], Training Loss: 0.1995, Training Accuracy: 0.9197
# Validation Loss: 0.6573, Validation Accuracy: 0.7542
# Class 0: Accuracy = 0.7277
# Class 1: Accuracy = 0.8132
# Class 2: Accuracy = 0.5802
# Epoch [18/30], Training Loss: 0.1924, Training Accuracy: 0.9236
# Validation Loss: 0.6816, Validation Accuracy: 0.7721
# Class 0: Accuracy = 0.7839
# Class 1: Accuracy = 0.7852
# Class 2: Accuracy = 0.5864
# Epoch [19/30], Training Loss: 0.1795, Training Accuracy: 0.9309
# Validation Loss: 0.6908, Validation Accuracy: 0.7725
# Class 0: Accuracy = 0.7894
# Class 1: Accuracy = 0.7790
# Class 2: Accuracy = 0.5885
# Epoch [20/30], Training Loss: 0.1786, Training Accuracy: 0.9300
# Validation Loss: 0.6721, Validation Accuracy: 0.7743
# Class 0: Accuracy = 0.8248
# Class 1: Accuracy = 0.7354
# Class 2: Accuracy = 0.6152
# Epoch [21/30], Training Loss: 0.1647, Training Accuracy: 0.9348
# Validation Loss: 0.7192, Validation Accuracy: 0.7672
# Class 0: Accuracy = 0.7778
# Class 1: Accuracy = 0.7809
# Class 2: Accuracy = 0.5885
# Epoch [22/30], Training Loss: 0.1667, Training Accuracy: 0.9359
# Validation Loss: 0.7060, Validation Accuracy: 0.7666
# Class 0: Accuracy = 0.8308
# Class 1: Accuracy = 0.7099
# Class 2: Accuracy = 0.6132
# Epoch [23/30], Training Loss: 0.1576, Training Accuracy: 0.9383
# Validation Loss: 0.7575, Validation Accuracy: 0.7703
# Class 0: Accuracy = 0.7800
# Class 1: Accuracy = 0.7886
# Class 2: Accuracy = 0.5679
# Epoch [24/30], Training Loss: 0.1574, Training Accuracy: 0.9393
# Validation Loss: 0.7505, Validation Accuracy: 0.7650
# Class 0: Accuracy = 0.7450
# Class 1: Accuracy = 0.8159
# Class 2: Accuracy = 0.5905
# Epoch [25/30], Training Loss: 0.1473, Training Accuracy: 0.9442
# Validation Loss: 0.7189, Validation Accuracy: 0.7697
# Class 0: Accuracy = 0.7899
# Class 1: Accuracy = 0.7714
# Class 2: Accuracy = 0.5905
# Epoch [26/30], Training Loss: 0.1453, Training Accuracy: 0.9455
# Validation Loss: 0.8022, Validation Accuracy: 0.7686
# Class 0: Accuracy = 0.7862
# Class 1: Accuracy = 0.7846
# Class 2: Accuracy = 0.5165
# Epoch [27/30], Training Loss: 0.1424, Training Accuracy: 0.9461
# Validation Loss: 0.7479, Validation Accuracy: 0.7744
# Class 0: Accuracy = 0.7958
# Class 1: Accuracy = 0.7806
# Class 2: Accuracy = 0.5556
# Epoch [28/30], Training Loss: 0.1419, Training Accuracy: 0.9462
# Validation Loss: 0.7604, Validation Accuracy: 0.7657
# Class 0: Accuracy = 0.8028
# Class 1: Accuracy = 0.7459
# Class 2: Accuracy = 0.5905
# Epoch [29/30], Training Loss: 0.1409, Training Accuracy: 0.9471
# Validation Loss: 0.7594, Validation Accuracy: 0.7704
# Class 0: Accuracy = 0.7718
# Class 1: Accuracy = 0.7984
# Class 2: Accuracy = 0.5720
# Epoch [30/30], Training Loss: 0.1350, Training Accuracy: 0.9489
# Validation Loss: 0.7815, Validation Accuracy: 0.7742
# Class 0: Accuracy = 0.7966
# Class 1: Accuracy = 0.7763
# Class 2: Accuracy = 0.5741

# %%
import matplotlib.pyplot as plt

# Plotting Loss and Accuracy
plt.figure(figsize=(12, 4))

# Plot Training Loss
plt.subplot(1, 2, 1)
plt.plot(train_losses, label='Training Loss')
plt.plot(val_losses, label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

# Plot Training Accuracy
plt.subplot(1, 2, 2)
plt.plot(train_accuracies, label='Training Accuracy', color='r')
plt.plot(val_accuracies, label='Validation Accuracy', color='g')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import accuracy_score

# Set the model to evaluation mode
model.eval()

# Initialize lists to store predicted and true labels
all_pred_labels = []
all_true_labels = []

# Iterate through the testing DataLoader
with torch.no_grad():  # Disable gradient computation for inference
    for batch_X_test, batch_y_test in test_loader:
        # Move the batch of data and labels to the device
        batch_X_test, batch_y_test = batch_X_test.to(device), batch_y_test.to(device)
        
        # Perform a forward pass through the model
        outputs_test = model(batch_X_test)
        
        # Compute the predicted labels
        _, predicted_test = torch.max(outputs_test, 1)
        
        # Accumulate the predicted labels and true labels
        all_pred_labels.extend(predicted_test.cpu().numpy())
        all_true_labels.extend(batch_y_test.cpu().numpy())

# Convert lists to NumPy arrays for further analysis
all_pred_labels = np.array(all_pred_labels)
all_true_labels = np.array(all_true_labels)

# Compute overall accuracy
accuracy_overall = accuracy_score(all_true_labels, all_pred_labels)
print(f"Overall Testing Accuracy: {accuracy_overall:.4f}")

# Compute class-wise accuracy
for i in range(3):  # Assuming 3 classes (wake, NREM, REM)
    class_accuracy = accuracy_score(all_true_labels == i, all_pred_labels == i)
    print(f"Class {i} Accuracy: {class_accuracy:.4f}")
# Out:
# Overall Testing Accuracy: 0.7742
# Class 0 Accuracy: 0.7973
# Class 1 Accuracy: 0.7917
# Class 2 Accuracy: 0.9594

# %%
# Define the file path to save the model
model_path = 'sleep_scoring_model_240109.pth'

# Save the model's state_dict to the file path
torch.save(model.state_dict(), model_path)

print(f"Model saved to {model_path}")
# Out:
# Model saved to sleep_scoring_model_240109.pth

# %%
# # Define the file path to load the model
# model_path = 'sleep_scoring_model_240109.pth'

# # Initialize a new model instance with the same architecture
# model = SleepScoringModel().to(device)

# # Load the model's state_dict from the file path
# model.load_state_dict(torch.load(model_path, map_location=device))

# print(f"Model loaded from {model_path}")

# %%
import numpy as np
from sklearn.preprocessing import StandardScaler

# Assume `data_new` is your new data with shape [number of samples, number of channels, length of each segment]

# Load the stored scalers
scalers_loaded = scalers  # Assuming `scalers` is the list of stored scalers from the training phase

# Initialize a list to store normalized data
normalized_data_new = []

# Apply the stored scalers to the new data
for sample in range(data_new.shape[0]):
    sample_data = []
    for channel in range(data_new.shape[1]):
        # Get the corresponding scaler for the channel
        scaler = scalers_loaded[sample * data_new.shape[1] + channel]
        
        # Apply the scaler to the channel data
        normalized_segment = scaler.transform(data_new[sample, channel, :].reshape((-1, 1)))
        
        sample_data.append(normalized_segment)
    
    # Stack the normalized channel data for the sample
    normalized_data_new.append(np.stack(sample_data, axis=0))

# Convert the list of normalized samples to a NumPy array
normalized_data_new = np.array(normalized_data_new)

# Reshape the normalized data to the desired shape
X_new = normalized_data_new.reshape((data_new.shape[0], data_new.shape[1], data_new.shape[2]))

# %%
# Assume `device` is already defined (e.g., device = torch.device('cuda' if torch.cuda.is_available() else 'cpu'))

# Define a function to preprocess a single sample of data
def preprocess_single_sample(single_sample):
    # Implement the preprocessing steps required for your model
    # ...
    return preprocessed_sample

# Define a function to make real-time predictions for a single sample
def predict_single_sample(model, single_sample):
    # Preprocess the single sample
    preprocessed_sample = preprocess_single_sample(single_sample)
    
    # Convert the preprocessed sample to a PyTorch tensor and move it to the device
    tensor_sample = torch.tensor(preprocessed_sample, dtype=torch.float32).unsqueeze(0).to(device)
    
    # Set the model to evaluation mode
    model.eval()
    
    # Perform a forward pass through the model
    with torch.no_grad():  # Disable gradient computation for inference
        outputs = model(tensor_sample)
    
    # Optionally, convert the predicted outputs to probabilities using a softmax function
    # probabilities = torch.softmax(outputs, dim=1)
    
    # Convert the predicted outputs to class labels
    _, predicted_label = torch.max(outputs, 1)
    
    # Convert the predicted class label to human-readable format
    class_label = convert_to_human_readable(predicted_label.item())  # Assume `convert_to_human_readable` is a function that converts numerical labels to human-readable format
    
    return class_label

# Example usage:
# single_sample = np.array([...])  # Replace with your single sample data
# predicted_class = predict_single_sample(model, single_sample)
# print(f"Predicted Class: {predicted_class}")
